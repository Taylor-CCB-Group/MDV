# %%
from mdvtools.mdvproject import MDVProject
import spatialdata as sd
# Out:
# /app/python/.venv/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(

# %% [markdown]
# ## Work in progress...
#
#
# Some things that would be good to do here:
# - Opening example datasets from spatialdata website
# - Making synthetic data, tests for covering things as per [the notebooks here](https://github.com/scverse/spatialdata-notebooks/tree/main/notebooks/developers_resources/storage_format), also `sd.datasets` seems to have methods for this.
# - Corresponding `Vitessce` and `MDV` configurations, conversions...

# %%
#sdata_remote = sd.read_zarr("https://storage.googleapis.com/vitessce-demo-data/spatialdata-october-2024/visium_associated_xenium_io_aligned.zarr")
# sdata_remote = sd.read_zarr("https://s3.embl.de/spatialdata/spatialdata-sandbox/visium_associated_xenium_io.zarr/")
mock_sdata = sd.datasets.blobs()
mock_sdata.write("/app/mdv/mock_sdata.zarr")
# Out:
# /app/python/.venv/lib/python3.12/site-packages/spatialdata/models/models.py:1144: UserWarning: Converting `region_key: region` to categorical dtype.
#   return convert_region_column_to_categorical(adata)
# INFO     The Zarr backing store has been changed from None the new file path: /app/mdv/mock_sdata.zarr

# %%
mock_sdata.images.keys()
# Out:
# dict_keys(['blobs_image', 'blobs_multiscale_image'])

# %%
path = "/app/mdv/114"
p = MDVProject(path)
sdata = sd.read_zarr(f"{path}/spatialdata.zarr")
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /app/python/.venv/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /app/python/.venv/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /app/python/.venv/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /app/python/.venv/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /app/python/.venv/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /app/python/.venv/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /app/python/.venv/lib/python3.12/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
image = sdata.images["morphology_focus"]

# %%
image
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /scale0
# │       Dimensions:  (c: 4, y: 3522, x: 5789)
# │       Coordinates:
# │         * c        (c) <U22 352B 'DAPI' ... 'AlphaSMA/Vimentin'
# │         * y        (y) float64 28kB 0.5 1.5 2.5 3.5 ... 3.52e+03 3.52e+03 3.522e+03
# │         * x        (x) float64 46kB 0.5 1.5 2.5 3.5 ... 5.786e+03 5.788e+03 5.788e+03
# │       Data variables:
# │           image    (c, y, x) uint16 163MB dask.array<chunksize=(1, 3522, 4096), meta=np.ndarray>
# ├── Group: /scale1
# │       Dimensions:  (c: 4, y: 1761, x: 2894)
# │       Coordinates:
# │         * c        (c) <U22 352B 'DAPI' ... 'AlphaSMA/Vimentin'
# │         * y        (y) float64 14kB 1.0 3.0 5.0 7.0 ... 3.517e+03 3.519e+03 3.521e+03
# │         * x        (x) float64 23kB 1.0 3.001 5.001 ... 5.784e+03 5.786e+03 5.788e+03
# │       Data variables:
# │           image    (c, y, x) uint16 41MB dask.array<chunksize=(1, 1761, 2894), meta=np.ndarray>
# ├── Group: /scale2
# │       Dimensions:  (c: 4, y: 880, x: 1447)
# │       Coordinates:
# │         * c        (c) <U22 352B 'DAPI' ... 'AlphaSMA/Vimentin'
# │         * y        (y) float64 7kB 2.001 6.003 10.01 ... 3.512e+03 3.516e+03 3.52e+03
# │         * x        (x) float64 12kB 2.0 6.001 10.0 ... 5.779e+03 5.783e+03 5.787e+03
# │       Data variables:
# │           image    (c, y, x) uint16 10MB dask.array<chunksize=(1, 880, 1447), meta=np.ndarray>
# ├── Group: /scale3
# │       Dimensions:  (c: 4, y: 440, x: 723)
# │       Coordinates:
# │         * c        (c) <U22 352B 'DAPI' ... 'AlphaSMA/Vimentin'
# │         * y        (y) float64 4kB 4.002 12.01 20.01 ... 3.502e+03 3.51e+03 3.518e+03
# │         * x        (x) float64 6kB 4.003 12.01 20.02 ... 5.769e+03 5.777e+03 5.785e+03
# │       Data variables:
# │           image    (c, y, x) uint16 3MB dask.array<chunksize=(1, 440, 723), meta=np.ndarray>
# └── Group: /scale4
#         Dimensions:  (c: 4, y: 220, x: 361)
#         Coordinates:
#           * c        (c) <U22 352B 'DAPI' ... 'AlphaSMA/Vimentin'
#           * y        (y) float64 2kB 8.005 24.01 40.02 ... 3.482e+03 3.498e+03 3.514e+03
#           * x        (x) float64 3kB 8.018 24.05 40.09 ... 5.749e+03 5.765e+03 5.781e+03
#         Data variables:
#             image    (c, y, x) uint16 635kB dask.array<chunksize=(1, 220, 361), meta=np.ndarray>

# %%
sd.transformations.get_transformation(image)
# Out:
# Identity

# %%
sdata.labels
# Out:
# {'cell_labels': <xarray.DataTree>
# Group: /
# ├── Group: /scale0
# │       Dimensions:  (y: 3522, x: 5789)
# │       Coordinates:
# │         * y        (y) float64 28kB 0.5 1.5 2.5 3.5 ... 3.52e+03 3.52e+03 3.522e+03
# │         * x        (x) float64 46kB 0.5 1.5 2.5 3.5 ... 5.786e+03 5.788e+03 5.788e+03
# │       Data variables:
# │           image    (y, x) uint32 82MB dask.array<chunksize=(3522, 4096), meta=np.ndarray>
# ├── Group: /scale1
# │       Dimensions:  (y: 1761, x: 2894)
# │       Coordinates:
# │         * y        (y) float64 14kB 1.0 3.0 5.0 7.0 ... 3.517e+03 3.519e+03 3.521e+03
# │         * x        (x) float64 23kB 1.0 3.001 5.001 ... 5.784e+03 5.786e+03 5.788e+03
# │       Data variables:
# │           image    (y, x) uint32 20MB dask.array<chunksize=(1761, 2894), meta=np.ndarray>
# ├── Group: /scale2
# │       Dimensions:  (y: 880, x: 1447)
# │       Coordinates:
# │         * y        (y) float64 7kB 2.001 6.003 10.01 ... 3.512e+03 3.516e+03 3.52e+03
# │         * x        (x) float64 12kB 2.0 6.001 10.0 ... 5.779e+03 5.783e+03 5.787e+03
# │       Data variables:
# │           image    (y, x) uint32 5MB dask.array<chunksize=(880, 1447), meta=np.ndarray>
# ├── Group: /scale3
# │       Dimensions:  (y: 440, x: 723)
# │       Coordinates:
# │         * y        (y) float64 4kB 4.002 12.01 20.01 ... 3.502e+03 3.51e+03 3.518e+03
# │         * x        (x) float64 6kB 4.003 12.01 20.02 ... 5.769e+03 5.777e+03 5.785e+03
# │       Data variables:
# │           image    (y, x) uint32 1MB dask.array<chunksize=(440, 723), meta=np.ndarray>
# └── Group: /scale4
#         Dimensions:  (y: 220, x: 361)
#         Coordinates:
#           * y        (y) float64 2kB 8.005 24.01 40.02 ... 3.482e+03 3.498e+03 3.514e+03
#           * x        (x) float64 3kB 8.018 24.05 40.09 ... 5.749e+03 5.765e+03 5.781e+03
#         Data variables:
#             image    (y, x) uint32 318kB dask.array<chunksize=(220, 361), meta=np.ndarray>, 'nucleus_labels': <xarray.DataTree>
# Group: /
# ├── Group: /scale0
# │       Dimensions:  (y: 3522, x: 5789)
# │       Coordinates:
# │         * y        (y) float64 28kB 0.5 1.5 2.5 3.5 ... 3.52e+03 3.52e+03 3.522e+03
# │         * x        (x) float64 46kB 0.5 1.5 2.5 3.5 ... 5.786e+03 5.788e+03 5.788e+03
# │       Data variables:
# │           image    (y, x) uint32 82MB dask.array<chunksize=(3522, 4096), meta=np.ndarray>
# ├── Group: /scale1
# │       Dimensions:  (y: 1761, x: 2894)
# │       Coordinates:
# │         * y        (y) float64 14kB 1.0 3.0 5.0 7.0 ... 3.517e+03 3.519e+03 3.521e+03
# │         * x        (x) float64 23kB 1.0 3.001 5.001 ... 5.784e+03 5.786e+03 5.788e+03
# │       Data variables:
# │           image    (y, x) uint32 20MB dask.array<chunksize=(1761, 2894), meta=np.ndarray>
# ├── Group: /scale2
# │       Dimensions:  (y: 880, x: 1447)
# │       Coordinates:
# │         * y        (y) float64 7kB 2.001 6.003 10.01 ... 3.512e+03 3.516e+03 3.52e+03
# │         * x        (x) float64 12kB 2.0 6.001 10.0 ... 5.779e+03 5.783e+03 5.787e+03
# │       Data variables:
# │           image    (y, x) uint32 5MB dask.array<chunksize=(880, 1447), meta=np.ndarray>
# ├── Group: /scale3
# │       Dimensions:  (y: 440, x: 723)
# │       Coordinates:
# │         * y        (y) float64 4kB 4.002 12.01 20.01 ... 3.502e+03 3.51e+03 3.518e+03
# │         * x        (x) float64 6kB 4.003 12.01 20.02 ... 5.769e+03 5.777e+03 5.785e+03
# │       Data variables:
# │           image    (y, x) uint32 1MB dask.array<chunksize=(440, 723), meta=np.ndarray>
# └── Group: /scale4
#         Dimensions:  (y: 220, x: 361)
#         Coordinates:
#           * y        (y) float64 2kB 8.005 24.01 40.02 ... 3.482e+03 3.498e+03 3.514e+03
#           * x        (x) float64 3kB 8.018 24.05 40.09 ... 5.749e+03 5.765e+03 5.781e+03
#         Data variables:
#             image    (y, x) uint32 318kB dask.array<chunksize=(220, 361), meta=np.ndarray>}
