# %%
import pandas as pd

# %%
import os
from mdvtools.mdvproject import MDVProject
from mdvtools.charts.row_chart import RowChart
from mdvtools.charts.dot_plot import DotPlot
from mdvtools.charts.histogram_plot import HistogramPlot
from mdvtools.charts.scatter_plot_3D import ScatterPlot3D
from mdvtools.charts.scatter_plot import ScatterPlot
from mdvtools.charts.table_plot import TablePlot
from mdvtools.charts.selection_dialog_plot import SelectionDialogPlot
from mdvtools.charts.violin_plot import ViolinPlot
from mdvtools.charts.box_plot import BoxPlot

# %%
df_bcell = pd.read_csv('df_bcell.csv')
bcell_gene_CD = pd.read_csv('bcell_gene_CD.csv')
bcell_gene_UC = pd.read_csv('bcell_gene_UC.csv')
bcell_umap_gene_short = pd.read_csv('bcell_umap_gene_short.csv')

bcell_gene_CD = bcell_gene_CD.set_index('index')
bcell_gene_UC = bcell_gene_UC.set_index('index')
df_bcell = df_bcell.set_index('index')
bcell_umap_gene_short = bcell_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/3440873742.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   bcell_umap_gene_short = pd.read_csv('bcell_umap_gene_short.csv')

# %%
bcell_gene_UC = bcell_gene_UC[bcell_gene_UC['Gene Expression'] > 0]
bcell_gene_CD = bcell_gene_CD[bcell_gene_CD['Gene Expression'] > 0]

# %%
df_cd4tcell = pd.read_csv('df_cd4tcell.csv')
cd4tcell_gene_CD = pd.read_csv('cd4tcell_gene_CD.csv')
cd4tcell_gene_UC = pd.read_csv('cd4tcell_gene_UC.csv')
cd4tcell_umap_gene_short = pd.read_csv('cd4tcell_umap_gene_short.csv')

cd4tcell_gene_CD = cd4tcell_gene_CD.set_index('index')
cd4tcell_gene_UC = cd4tcell_gene_UC.set_index('index')
df_cd4tcell = df_cd4tcell.set_index('index')
cd4tcell_umap_gene_short = cd4tcell_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/3816023568.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   cd4tcell_umap_gene_short = pd.read_csv('cd4tcell_umap_gene_short.csv')

# %%
cd4tcell_gene_UC = cd4tcell_gene_UC[cd4tcell_gene_UC['Gene Expression'] > 0]
cd4tcell_gene_CD = cd4tcell_gene_CD[cd4tcell_gene_CD['Gene Expression'] > 0]

# %%
df_cd8tcell = pd.read_csv('df_cd8tcell.csv')
cd8tcell_gene_CD = pd.read_csv('cd8tcell_gene_CD.csv')
cd8tcell_gene_UC = pd.read_csv('cd8tcell_gene_UC.csv')
cd8tcell_umap_gene_short = pd.read_csv('cd8tcell_umap_gene_short.csv')

cd8tcell_gene_CD = cd8tcell_gene_CD.set_index('index')
cd8tcell_gene_UC = cd8tcell_gene_UC.set_index('index')
df_cd8tcell = df_cd8tcell.set_index('index')
cd8tcell_umap_gene_short = cd8tcell_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/2843045801.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   cd8tcell_umap_gene_short = pd.read_csv('cd8tcell_umap_gene_short.csv')

# %%
cd8tcell_gene_UC = cd8tcell_gene_UC[cd8tcell_gene_UC['Gene Expression'] > 0]
cd8tcell_gene_CD = cd8tcell_gene_CD[cd8tcell_gene_CD['Gene Expression'] > 0]

# %%
df_cd8tcell = df_cd8tcell.rename(columns={'sample_id':'Sample ID'})

# %%
df_endothelium = pd.read_csv('df_endothelium.csv')
endothelium_gene_CD = pd.read_csv('endothelium_gene_CD.csv')
endothelium_gene_UC = pd.read_csv('endothelium_gene_UC.csv')
endothelium_umap_gene_short = pd.read_csv('endothelium_umap_gene_short.csv')

endothelium_gene_CD = endothelium_gene_CD.set_index('index')
endothelium_gene_UC = endothelium_gene_UC.set_index('index')
df_endothelium = df_endothelium.set_index('index')
endothelium_umap_gene_short = endothelium_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/1428419317.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   endothelium_umap_gene_short = pd.read_csv('endothelium_umap_gene_short.csv')

# %%
endothelium_gene_UC = endothelium_gene_UC[endothelium_gene_UC['Gene Expression']>0]
endothelium_gene_CD = endothelium_gene_CD[endothelium_gene_CD['Gene Expression']>0]

# %%
df_epi_ileal = pd.read_csv('df_epi_ileal.csv')
epi_ileal_gene_CD = pd.read_csv('epi_ileal_gene_CD.csv')
epi_ileal_gene_UC = pd.read_csv('epi_ileal_gene_UC.csv')
epi_ileal_umap_gene_short = pd.read_csv('epi_ileal_umap_gene_short.csv')

epi_ileal_gene_CD = epi_ileal_gene_CD.set_index('index')
epi_ileal_gene_UC = epi_ileal_gene_UC.set_index('index')
df_epi_ileal = df_epi_ileal.set_index('index')
epi_ileal_umap_gene_short = epi_ileal_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/3619190750.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   epi_ileal_umap_gene_short = pd.read_csv('epi_ileal_umap_gene_short.csv')

# %%
epi_ileal_gene_UC = epi_ileal_gene_UC[epi_ileal_gene_UC['Gene Expression']>0]
epi_ileal_gene_CD = epi_ileal_gene_CD[epi_ileal_gene_CD['Gene Expression']>0]

# %%
df_fib_peri = pd.read_csv('df_fib_peri.csv')
fib_peri_gene_CD = pd.read_csv('fib_peri_gene_CD.csv')
fib_peri_gene_UC = pd.read_csv('fib_peri_gene_UC.csv')
fib_peri_umap_gene_short = pd.read_csv('fib_peri_umap_gene_short.csv')

fib_peri_gene_CD = fib_peri_gene_CD.set_index('index')
fib_peri_gene_UC = fib_peri_gene_UC.set_index('index')
df_fib_peri = df_fib_peri.set_index('index')
fib_peri_umap_gene_short = fib_peri_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/940746172.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   fib_peri_umap_gene_short = pd.read_csv('fib_peri_umap_gene_short.csv')

# %%
fib_peri_gene_UC = fib_peri_gene_UC[fib_peri_gene_UC['Gene Expression']>0]
fib_peri_gene_CD = fib_peri_gene_CD[fib_peri_gene_CD['Gene Expression']>0]

# %%
df_ilc = pd.read_csv('df_ilc.csv')
ilc_gene_CD = pd.read_csv('ilc_gene_CD.csv')
ilc_gene_UC = pd.read_csv('ilc_gene_UC.csv')
ilc_umap_gene_short = pd.read_csv('ilc_umap_gene_short.csv')

ilc_gene_CD = ilc_gene_CD.set_index('index')
ilc_gene_UC = ilc_gene_UC.set_index('index')
df_ilc = df_ilc.set_index('index')
ilc_umap_gene_short = ilc_umap_gene_short.set_index('index')

# %%
ilc_gene_UC = ilc_gene_UC[ilc_gene_UC['Gene Expression']>0]
ilc_gene_CD = ilc_gene_CD[ilc_gene_CD['Gene Expression']>0]

# %%
df_myeloid = pd.read_csv('df_myeloid.csv')
myeloid_gene_CD = pd.read_csv('myeloid_gene_CD.csv')
myeloid_gene_UC = pd.read_csv('myeloid_gene_UC.csv')
myeloid_umap_gene_short = pd.read_csv('myeloid_umap_gene_short.csv')

myeloid_gene_CD = myeloid_gene_CD.set_index('index')
myeloid_gene_UC = myeloid_gene_UC.set_index('index')
df_myeloid = df_myeloid.set_index('index')
myeloid_umap_gene_short = myeloid_umap_gene_short.set_index('index')

# %%
myeloid_gene_UC = myeloid_gene_UC[myeloid_gene_UC['Gene Expression']>0]
myeloid_gene_CD = myeloid_gene_CD[myeloid_gene_CD['Gene Expression']>0]

# %%
df_plasmacell = pd.read_csv('df_plasmacell.csv')
plasmacell_gene_CD = pd.read_csv('plasmacell_gene_CD.csv')
plasmacell_gene_UC = pd.read_csv('plasmacell_gene_UC.csv')
plasmacell_umap_gene_short = pd.read_csv('plasmacell_umap_gene_short.csv')

plasmacell_gene_CD = plasmacell_gene_CD.set_index('index')
plasmacell_gene_UC = plasmacell_gene_UC.set_index('index')
df_plasmacell = df_plasmacell.set_index('index')
plasmacell_umap_gene_short = plasmacell_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/1039097512.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   plasmacell_umap_gene_short = pd.read_csv('plasmacell_umap_gene_short.csv')

# %%
plasmacell_gene_UC = plasmacell_gene_UC[plasmacell_gene_UC['Gene Expression']>0]
plasmacell_gene_CD = plasmacell_gene_CD[plasmacell_gene_CD['Gene Expression']>0]

# %%
df_epithelium = pd.read_csv('df_epithelium.csv')
epithelium_gene_CD = pd.read_csv('epithelium_gene_CD_resampled.csv')
epithelium_gene_UC = pd.read_csv('epithelium_gene_UC_resampled.csv')
epithelium_umap_gene_short = pd.read_csv('epithelium_umap_gene_short.csv')

epithelium_gene_CD = epithelium_gene_CD.set_index('index')
epithelium_gene_UC = epithelium_gene_UC.set_index('index')
df_epithelium = df_epithelium.set_index('index')
epithelium_umap_gene_short = epithelium_umap_gene_short.set_index('index')
# Out:
# /var/folders/xf/lj2gr_2s7txb29m_mkg78h_80000gn/T/ipykernel_63229/1735688851.py:4: DtypeWarning: Columns (7,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   epithelium_umap_gene_short = pd.read_csv('epithelium_umap_gene_short.csv')

# %%
epithelium_gene_UC = epithelium_gene_UC[epithelium_gene_UC['Gene Expression']>0]
epithelium_gene_CD = epithelium_gene_CD[epithelium_gene_CD['Gene Expression']>0]

# %%
bcell_CD_proportion = pd.read_csv('bcell_CD_proportion.csv').drop(columns = 'Unnamed: 0')
bcell_UC_proportion = pd.read_csv('bcell_UC_proportion.csv').drop(columns = 'Unnamed: 0')

cd4tcell_CD_proportion = pd.read_csv('cd4tcell_CD_proportion.csv').drop(columns = 'Unnamed: 0')
cd4tcell_UC_proportion = pd.read_csv('cd4tcell_UC_proportion.csv').drop(columns = 'Unnamed: 0')

cd8tcell_CD_proportion = pd.read_csv('cd8tcell_CD_proportion.csv').drop(columns = 'Unnamed: 0')
cd8tcell_UC_proportion = pd.read_csv('cd8tcell_UC_proportion.csv').drop(columns = 'Unnamed: 0')

endothelium_CD_proportion = pd.read_csv('endothelium_CD_proportion.csv').drop(columns = 'Unnamed: 0')
endothelium_UC_proportion = pd.read_csv('endothelium_UC_proportion.csv').drop(columns = 'Unnamed: 0')

epi_ileal_CD_proportion = pd.read_csv('epi_ileal_CD_proportion.csv').drop(columns = 'Unnamed: 0')
epi_ileal_UC_proportion = pd.read_csv('epi_ileal_UC_proportion.csv').drop(columns = 'Unnamed: 0')

epithelium_CD_proportion = pd.read_csv('epithelium_CD_resampled_proportion.csv').drop(columns = 'Unnamed: 0')
epithelium_UC_proportion = pd.read_csv('epithelium_UC_resampled_proportion.csv').drop(columns = 'Unnamed: 0')

fib_peri_CD_proportion = pd.read_csv('fib_peri_CD_proportion.csv').drop(columns = 'Unnamed: 0')
fib_peri_UC_proportion = pd.read_csv('fib_peri_UC_proportion.csv').drop(columns = 'Unnamed: 0')

ilc_CD_proportion = pd.read_csv('ilc_CD_proportion.csv').drop(columns = 'Unnamed: 0')
ilc_UC_proportion = pd.read_csv('ilc_UC_proportion.csv').drop(columns = 'Unnamed: 0')

myeloid_CD_proportion = pd.read_csv('myeloid_CD_proportion.csv').drop(columns = 'Unnamed: 0')
myeloid_UC_proportion = pd.read_csv('myeloid_UC_proportion.csv').drop(columns = 'Unnamed: 0')

plasmacell_CD_proportion = pd.read_csv('plasmacell_CD_proportion.csv').drop(columns = 'Unnamed: 0')
plasmacell_UC_proportion = pd.read_csv('plasmacell_UC_proportion.csv').drop(columns = 'Unnamed: 0')

# %%
bcell_abundance = pd.read_csv('bcell_abundance.csv').drop(columns = 'Unnamed: 0')
cd4tcell_abundance = pd.read_csv('cd4tcell_abundance.csv').drop(columns = 'Unnamed: 0')
cd8tcell_abundance = pd.read_csv('cd8tcell_abundance.csv').drop(columns = 'Unnamed: 0')
endothelium_abundance = pd.read_csv('endothelium_abundance.csv').drop(columns = 'Unnamed: 0')
epi_ileal_abundance = pd.read_csv('epi_ileal_abundance.csv').drop(columns = 'Unnamed: 0')
fib_peri_abundance = pd.read_csv('fib_peri_abundance.csv').drop(columns = 'Unnamed: 0')
ilc_abundance = pd.read_csv('ilc_abundance.csv').drop(columns = 'Unnamed: 0')
epithelium_abundance = pd.read_csv('epithelium_abundance.csv').drop(columns = 'Unnamed: 0')
myeloid_abundance = pd.read_csv('myeloid_abundance.csv').drop(columns = 'Unnamed: 0')
plasmacell_abundance = pd.read_csv('plasmacell_abundance.csv').drop(columns = 'Unnamed: 0')

# %%
df_bcell = df_bcell.drop(columns=['Remission'])
df_cd8tcell = df_cd8tcell.drop(columns=['Remission'])
df_cd4tcell = df_cd4tcell.drop(columns=['Remission'])
df_endothelium = df_endothelium.drop(columns=['Remission'])
df_epi_ileal = df_epi_ileal.drop(columns=['Remission'])
df_fib_peri = df_fib_peri.drop(columns=['Remission'])
df_ilc = df_ilc.drop(columns=['Remission'])
df_epithelium = df_epithelium.drop(columns=['Remission'])
df_myeloid = df_myeloid.drop(columns=['Remission'])
df_plasmacell = df_plasmacell.drop(columns=['Remission'])

# %%
bcell_umap_gene_short = bcell_umap_gene_short.drop(columns=['Remission'])
cd4tcell_umap_gene_short = cd4tcell_umap_gene_short.drop(columns=['Remission'])
cd8tcell_umap_gene_short = cd8tcell_umap_gene_short.drop(columns=['Remission'])
endothelium_umap_gene_short = endothelium_umap_gene_short.drop(columns=['Remission'])
epi_ileal_umap_gene_short = epi_ileal_umap_gene_short.drop(columns=['Remission'])
fib_peri_umap_gene_short = fib_peri_umap_gene_short.drop(columns=['Remission'])
ilc_umap_gene_short = ilc_umap_gene_short.drop(columns=['Remission'])
epithelium_gene_short = epithelium_umap_gene_short.drop(columns=['Remission'])
myeloid_umap_gene_short = myeloid_umap_gene_short.drop(columns=['Remission'])
plasmacell_umap_gene_short = plasmacell_umap_gene_short.drop(columns=['Remission'])

# %%
df_cd8tcell = df_cd8tcell.rename(columns={'sample_id':'Sample ID'})
df_cd4tcell = df_cd4tcell.rename(columns={'sample_id':'Sample ID'})
df_endothelium = df_endothelium.rename(columns={'sample_id':'Sample ID'})
df_epi_ileal = df_epi_ileal.rename(columns={'sample_id':'Sample ID'})
df_fib_peri = df_fib_peri.rename(columns={'sample_id':'Sample ID'})
df_ilc = df_ilc.rename(columns={'sample_id':'Sample ID'})
df_epithelium = df_epithelium.rename(columns={'sample_id':'Sample ID'})
df_myeloid = df_myeloid.rename(columns={'sample_id': 'Sample ID'})
df_plasmacell = df_plasmacell.rename(columns={'sample_id':'Sample ID'})

# %%
bcell_umap_gene_short = bcell_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
cd4tcell_umap_gene_short = cd4tcell_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
cd8tcell_umap_gene_short = cd8tcell_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
endothelium_umap_gene_short = endothelium_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
epi_ileal_umap_gene_short = epi_ileal_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
fib_peri_umap_gene_short = fib_peri_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
ilc_umap_gene_short = ilc_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
epithelium_umap_gene_short = epithelium_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
myeloid_umap_gene_short = myeloid_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})
plasmacell_umap_gene_short = plasmacell_umap_gene_short.rename(columns={'sample_id': 'Sample ID'})

# %%
# df_bcell = df_bcell.iloc[:100,:]
# df_cd8tcell = df_cd8tcell.iloc[:100,:]
# df_cd4tcell = df_cd4tcell.iloc[:100,:]
# df_endothelium = df_endothelium.iloc[:100,:]
# df_epi_ileal = df_epi_ileal.iloc[:100,:]
# df_fib_peri = df_fib_peri.iloc[:100,:]
# df_ilc = df_ilc.iloc[:100,:]
# #df_epithelium
# df_myeloid = df_myeloid.iloc[:100,:]
# df_plasmacell = df_plasmacell.iloc[:100,:]

# %%
# bcell_umap_gene_short = bcell_umap_gene_short.iloc[:100,:]
# cd4tcell_umap_gene_short = cd4tcell_umap_gene_short.iloc[:100,:]
# cd8tcell_umap_gene_short = cd8tcell_umap_gene_short.iloc[:100,:]
# endothelium_umap_gene_short = endothelium_umap_gene_short.iloc[:100,:]
# epi_ileal_umap_gene_short = epi_ileal_umap_gene_short.iloc[:100,:]
# fib_peri_umap_gene_short = fib_peri_umap_gene_short.iloc[:100,:]
# ilc_umap_gene_short = ilc_umap_gene_short.iloc[:100,:]
# myeloid_umap_gene_short = myeloid_umap_gene_short.iloc[:100,:]
# plasmacell_umap_gene_short = plasmacell_umap_gene_short.iloc[:100,:]

# %% [markdown]
# ## Filtering for positive gene expression

# %%
# bcell_gene_UC = bcell_gene_UC[bcell_gene_UC['Gene Expression'] > 0]
# cd4tcell_gene_UC = cd4tcell_gene_UC[cd4tcell_gene_UC['Gene Expression'] > 0]
# cd8tcell_gene_UC = cd8tcell_gene_UC[cd8tcell_gene_UC['Gene Expression'] > 0]
# endothelium_gene_UC = endothelium_gene_UC[endothelium_gene_UC['Gene Expression']>0]
# epi_ileal_gene_UC = epi_ileal_gene_UC[epi_ileal_gene_UC['Gene Expression']>0]
# fib_peri_gene_UC = fib_peri_gene_UC[fib_peri_gene_UC['Gene Expression']>0]
# ilc_gene_UC = ilc_gene_UC[ilc_gene_UC['Gene Expression']>0]
# myeloid_gene_UC = myeloid_gene_UC[myeloid_gene_UC['Gene Expression']>0]
# plasmacell_gene_UC = plasmacell_gene_UC[plasmacell_gene_UC['Gene Expression']>0]
# epithelium_gene_UC = epithelium_gene_UC[epithelium_gene_UC['Gene Expression']>0]

# %%
# bcell_gene_CD = bcell_gene_CD[bcell_gene_CD['Gene Expression'] > 0]
# cd4tcell_gene_CD = cd4tcell_gene_CD[cd4tcell_gene_CD['Gene Expression'] > 0]
# cd8tcell_gene_CD = cd8tcell_gene_CD[cd8tcell_gene_CD['Gene Expression'] > 0]
# endothelium_gene_CD = endothelium_gene_CD[endothelium_gene_CD['Gene Expression']>0]
# epi_ileal_gene_CD = epi_ileal_gene_CD[epi_ileal_gene_CD['Gene Expression']>0]
# fib_peri_gene_CD = fib_peri_gene_CD[fib_peri_gene_CD['Gene Expression']>0]
# ilc_gene_CD = ilc_gene_CD[ilc_gene_CD['Gene Expression']>0]
# myeloid_gene_CD = myeloid_gene_CD[myeloid_gene_CD['Gene Expression']>0]
# plasmacell_gene_CD = plasmacell_gene_CD[plasmacell_gene_CD['Gene Expression']>0]
# epithelium_gene_CD = epithelium_gene_CD[epithelium_gene_CD['Gene Expression']>0]

# %%
# setting up and serving the MDV project
base = os.path.expanduser('~/mdv')
project_path = os.path.join(base, 'taurus') # defining the location where the project metadata will be stored
p = MDVProject(os.path.expanduser(project_path), delete_existing=True)

# adding the two data sources to the project
p.add_datasource("B cells metadata 1", df_bcell)
p.add_datasource("B cells metadata 2", bcell_umap_gene_short)
p.add_datasource("B cells expression CD", bcell_gene_CD)
p.add_datasource("B cells expression UC", bcell_gene_UC)
# * * * * * * 
p.add_datasource("CD4+ T cells metadata 1", df_cd4tcell)
p.add_datasource("CD4+ T cells metadata 2", cd4tcell_umap_gene_short)
p.add_datasource("CD4+ T cells expression CD", cd4tcell_gene_CD)
p.add_datasource("CD4+ T cells expression UC", cd4tcell_gene_UC)
# * * * * * * 
p.add_datasource("CD8+ T cells metadata 1", df_cd8tcell)
p.add_datasource("CD8+ T cells metadata 2", cd8tcell_umap_gene_short)
p.add_datasource("CD8+ T cells expression CD", cd8tcell_gene_CD)
p.add_datasource("CD8+ T cells expression UC", cd8tcell_gene_UC)
# * * * * * * 
p.add_datasource("Endothelial cells metadata 1", df_endothelium)
p.add_datasource("Endothelial cells metadata 2", endothelium_umap_gene_short)
p.add_datasource("Endothelial cells expression CD", endothelium_gene_CD)
p.add_datasource("Endothelial cells expression UC", endothelium_gene_UC)
# * * * * * * 
p.add_datasource("Ileal epithelial cells metadata 1", df_epi_ileal)
p.add_datasource("Ileal epithelial cells metadata 2", epi_ileal_umap_gene_short)
p.add_datasource("Ileal epithelial cells expression CD", epi_ileal_gene_CD)
p.add_datasource("Ileal epithelial cells expression UC", epi_ileal_gene_UC)
# * * * * * * 
p.add_datasource("Colonic epithelial cells metadata 1", df_epithelium)
p.add_datasource("Colonic epithelial cells metadata 2", epithelium_umap_gene_short)
p.add_datasource("Colonic epithelial cells expression CD", epithelium_gene_CD)
p.add_datasource("Colonic epithelial cells expression UC", epithelium_gene_UC)
# * * * * * * 
p.add_datasource("Fibroblast pericyte cells metadata 1", df_fib_peri)
p.add_datasource("Fibroblast pericyte cells metadata 2", fib_peri_umap_gene_short)
p.add_datasource("Fibroblast pericyte cells expression CD", fib_peri_gene_CD)
p.add_datasource("Fibroblast pericyte cells expression UC", fib_peri_gene_UC)
# * * * * * * 
p.add_datasource("Innate lymphoid cells metadata 1", df_ilc)
p.add_datasource("Innate lymphoid cells metadata 2", ilc_umap_gene_short)
p.add_datasource("Innate lymphoid cells expression CD", ilc_gene_CD)
p.add_datasource("Innate lymphoid cells expression UC", ilc_gene_UC)
# * * * * * * 
p.add_datasource("Myeloid cells metadata 1", df_myeloid)
p.add_datasource("Myeloid cells metadata 2", myeloid_umap_gene_short)
p.add_datasource("Myeloid cells expression CD", myeloid_gene_CD)
p.add_datasource("Myeloid cells expression UC", myeloid_gene_UC)
# * * * * * * 
p.add_datasource("Plasma cells metadata 1", df_plasmacell)
p.add_datasource("Plasma cells metadata 2", plasmacell_umap_gene_short)
p.add_datasource("Plasma cells expression CD", plasmacell_gene_CD)
p.add_datasource("Plasma cells expression UC", plasmacell_gene_UC)
# Out:
# []

# %%
p.add_datasource("B cells expression proportion CD", bcell_CD_proportion)
p.add_datasource("B cells expression proportion UC", bcell_UC_proportion)

p.add_datasource("CD4+ T cells expression proportion CD", cd4tcell_CD_proportion)
p.add_datasource("CD4+ T cells expression proportion UC", cd4tcell_UC_proportion)

p.add_datasource("CD8+ T cells expression proportion CD", cd8tcell_CD_proportion)
p.add_datasource("CD8+ T cells expression proportion UC", cd8tcell_UC_proportion)

p.add_datasource("Endothelial cells expression proportion CD", endothelium_CD_proportion)
p.add_datasource("Endothelial cells expression proportion UC", endothelium_UC_proportion)

p.add_datasource("Ileal epithelial cells expression proportion CD", epi_ileal_CD_proportion)
p.add_datasource("Ileal epithelial cells expression proportion UC", epi_ileal_UC_proportion)

p.add_datasource("Fibroblast pericyte cells expression proportion CD", fib_peri_CD_proportion)
p.add_datasource("Fibroblast pericyte cells expression proportion UC", fib_peri_UC_proportion)

p.add_datasource("Innate lymphoid cells expression proportion CD", ilc_CD_proportion)
p.add_datasource("Innate lymphoid cells expression proportion UC", ilc_UC_proportion)

p.add_datasource("Myeloid cells expression proportion CD", myeloid_CD_proportion)
p.add_datasource("Myeloid cells expression proportion UC", myeloid_UC_proportion)

p.add_datasource("Plasma cells expression proportion CD", plasmacell_CD_proportion)
p.add_datasource("Plasma cells expression proportion UC", plasmacell_UC_proportion)
# Out:
# []

# %%
p.add_datasource("Colonic epithelial cells expression proportion CD", epithelium_CD_proportion)
p.add_datasource("Colonic epithelial cells expression proportion UC", epithelium_UC_proportion)
# Out:
# []

# %%
p.add_datasource("B cells metadata 3", bcell_abundance)

p.add_datasource("CD4+ T cells metadata 3", cd4tcell_abundance)

p.add_datasource("CD8+ T cells metadata 3", cd8tcell_abundance)

p.add_datasource("Endothelial cells metadata 3", endothelium_abundance)

p.add_datasource("Ileal epithelial cells metadata 3", epi_ileal_abundance)

p.add_datasource("Fibroblast pericyte cells metadata 3", fib_peri_abundance)

p.add_datasource("Innate lymphoid cells metadata 3", ilc_abundance)

p.add_datasource("Myeloid cells metadata 3", myeloid_abundance)

p.add_datasource("Plasma cells metadata 3", plasmacell_abundance)

p.add_datasource("Colonic epithelial cells metadata 3", epithelium_abundance)
# Out:
# []

# %%
### adding an empty dataframe for the Landing page

empty = pd.DataFrame({'Summary' : []})

#empty

p.add_datasource("Summary", empty)
# Out:
# /Users/mariak/Documents/MDVmk/MDV/python/mdvtools/mdvproject.py:699: UserWarning: cannot add column 'Summary' to datasource 'Summary':
# ValueError('zero-size array to reduction operation minimum which has no identity')
#   warnings.warn(
# ['Summary']

# %%
# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_bcells = ScatterPlot(
    title="B cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_bcells.set_default_color("#377eb8")
scatter2D_plot_bcells.set_brush("poly")
scatter2D_plot_bcells.set_opacity(0.8)
scatter2D_plot_bcells.set_radius(2)
scatter2D_plot_bcells.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_bcells.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_bcells.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_bcells.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_cd4t = ScatterPlot(
    title="CD4+ T cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_cd4t.set_default_color("#377eb8")
scatter2D_plot_cd4t.set_brush("poly")
scatter2D_plot_cd4t.set_opacity(0.8)
scatter2D_plot_cd4t.set_radius(2)
scatter2D_plot_cd4t.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_cd4t.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd4t.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd4t.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_cd8t = ScatterPlot(
    title="CD8+ T cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_cd8t.set_default_color("#377eb8")
scatter2D_plot_cd8t.set_brush("poly")
scatter2D_plot_cd8t.set_opacity(0.8)
scatter2D_plot_cd8t.set_radius(2)
scatter2D_plot_cd8t.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_cd8t.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd8t.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd8t.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_endothelium = ScatterPlot(
    title="Endothelial cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_endothelium.set_default_color("#377eb8")
scatter2D_plot_endothelium.set_brush("poly")
scatter2D_plot_endothelium.set_opacity(0.8)
scatter2D_plot_endothelium.set_radius(2)
scatter2D_plot_endothelium.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_endothelium.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_endothelium.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_endothelium.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_epithelial = ScatterPlot(
    title="Ileal epithelial cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_epithelial.set_default_color("#377eb8")
scatter2D_plot_epithelial.set_brush("poly")
scatter2D_plot_epithelial.set_opacity(0.8)
scatter2D_plot_epithelial.set_radius(2)
scatter2D_plot_epithelial.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_epithelial.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelial.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelial.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_epithelium = ScatterPlot(
    title="Colonic epithelial cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_epithelium.set_default_color("#377eb8")
scatter2D_plot_epithelium.set_brush("poly")
scatter2D_plot_epithelium.set_opacity(0.8)
scatter2D_plot_epithelium.set_radius(2)
scatter2D_plot_epithelium.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_epithelium.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelium.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelium.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_fib_peri= ScatterPlot(
    title="Fibroblast pericyte cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_fib_peri.set_default_color("#377eb8")
scatter2D_plot_fib_peri.set_brush("poly")
scatter2D_plot_fib_peri.set_opacity(0.8)
scatter2D_plot_fib_peri.set_radius(2)
scatter2D_plot_fib_peri.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_fib_peri.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_fib_peri.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_fib_peri.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_ilc= ScatterPlot(
    title="Innate lymphoid cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_ilc.set_default_color("#377eb8")
scatter2D_plot_ilc.set_brush("poly")
scatter2D_plot_ilc.set_opacity(0.8)
scatter2D_plot_ilc.set_radius(2)
scatter2D_plot_ilc.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_ilc.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_ilc.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_ilc.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_myeloid= ScatterPlot(
    title="Myeloid cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_myeloid.set_default_color("#377eb8")
scatter2D_plot_myeloid.set_brush("poly")
scatter2D_plot_myeloid.set_opacity(0.8)
scatter2D_plot_myeloid.set_radius(2)
scatter2D_plot_myeloid.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_myeloid.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_myeloid.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_myeloid.set_color_by("Cell states")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_plasma= ScatterPlot(
    title="Plasma cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_plasma.set_default_color("#377eb8")
scatter2D_plot_plasma.set_brush("poly")
scatter2D_plot_plasma.set_opacity(0.8)
scatter2D_plot_plasma.set_radius(2)
scatter2D_plot_plasma.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_plasma.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_plasma.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_plasma.set_color_by("Cell states")

# %%
# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_bcells_genes = ScatterPlot(
    title="B cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_bcells_genes.set_default_color("#377eb8")
scatter2D_plot_bcells_genes.set_brush("poly")
scatter2D_plot_bcells_genes.set_opacity(0.8)
scatter2D_plot_bcells_genes.set_radius(2)
scatter2D_plot_bcells_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_bcells_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_bcells_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_bcells_genes.set_color_by("HSPE1")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_cd4t_genes = ScatterPlot(
    title="CD4+ T cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_cd4t_genes.set_default_color("#377eb8")
scatter2D_plot_cd4t_genes.set_brush("poly")
scatter2D_plot_cd4t_genes.set_opacity(0.8)
scatter2D_plot_cd4t_genes.set_radius(2)
scatter2D_plot_cd4t_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_cd4t_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd4t_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd4t_genes.set_color_by("HSPE1")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_cd8t_genes = ScatterPlot(
    title="CD8+ T cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_cd8t_genes.set_default_color("#377eb8")
scatter2D_plot_cd8t_genes.set_brush("poly")
scatter2D_plot_cd8t_genes.set_opacity(0.8)
scatter2D_plot_cd8t_genes.set_radius(2)
scatter2D_plot_cd8t_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_cd8t_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd8t_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_cd8t_genes.set_color_by("HSPE1")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_endothelium_genes = ScatterPlot(
    title="Endothelial cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_endothelium_genes.set_default_color("#377eb8")
scatter2D_plot_endothelium_genes.set_brush("poly")
scatter2D_plot_endothelium_genes.set_opacity(0.8)
scatter2D_plot_endothelium_genes.set_radius(2)
scatter2D_plot_endothelium_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_endothelium_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_endothelium_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_endothelium_genes.set_color_by("LINC02513")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_epithelial_genes = ScatterPlot(
    title="Ileal epithelial cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_epithelial_genes.set_default_color("#377eb8")
scatter2D_plot_epithelial_genes.set_brush("poly")
scatter2D_plot_epithelial_genes.set_opacity(0.8)
scatter2D_plot_epithelial_genes.set_radius(2)
scatter2D_plot_epithelial_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_epithelial_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelial_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelial_genes.set_color_by("HSPE1")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_epithelium_genes = ScatterPlot(
    title="Colonic epithelial cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_epithelium_genes.set_default_color("#377eb8")
scatter2D_plot_epithelium_genes.set_brush("poly")
scatter2D_plot_epithelium_genes.set_opacity(0.8)
scatter2D_plot_epithelium_genes.set_radius(2)
scatter2D_plot_epithelium_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_epithelium_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelium_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_epithelium_genes.set_color_by("SELENBP1")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_fib_peri_genes= ScatterPlot(
    title="Fibroblast pericyte cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_fib_peri_genes.set_default_color("#377eb8")
scatter2D_plot_fib_peri_genes.set_brush("poly")
scatter2D_plot_fib_peri_genes.set_opacity(0.8)
scatter2D_plot_fib_peri_genes.set_radius(2)
scatter2D_plot_fib_peri_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_fib_peri_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_fib_peri_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_fib_peri_genes.set_color_by("ACTA2")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_ilc_genes= ScatterPlot(
    title="Innate lymphoid cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_ilc_genes.set_default_color("#377eb8")
scatter2D_plot_ilc_genes.set_brush("poly")
scatter2D_plot_ilc_genes.set_opacity(0.8)
scatter2D_plot_ilc_genes.set_radius(2)
scatter2D_plot_ilc_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_ilc_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_ilc_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_ilc_genes.set_color_by("HSPE1")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_myeloid_genes= ScatterPlot(
    title="Myeloid cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_myeloid_genes.set_default_color("#377eb8")
scatter2D_plot_myeloid_genes.set_brush("poly")
scatter2D_plot_myeloid_genes.set_opacity(0.8)
scatter2D_plot_myeloid_genes.set_radius(2)
scatter2D_plot_myeloid_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_myeloid_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_myeloid_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_myeloid_genes.set_color_by("A2M")

# creating a scatter plot using the ScatterPlot implementation to show the 2 PCA clustering components
scatter2D_plot_plasma_genes= ScatterPlot(
    title="Plasma cells",
    params=["UMAP_1", "UMAP_2"],
    size=[400, 400],
    position=[10, 10]
)

# configuring the scatter plot
scatter2D_plot_plasma_genes.set_default_color("#377eb8")
scatter2D_plot_plasma_genes.set_brush("poly")
scatter2D_plot_plasma_genes.set_opacity(0.8)
scatter2D_plot_plasma_genes.set_radius(2)
scatter2D_plot_plasma_genes.set_color_legend(display=True, position=[50, 5])
scatter2D_plot_plasma_genes.set_axis_properties("x", {"label": "UMAP 1", "textSize": 13, "tickfont": 10})
scatter2D_plot_plasma_genes.set_axis_properties("y", {"label": "UMAP 2", "textSize": 13, "tickfont": 10})
scatter2D_plot_plasma_genes.set_color_by("HSPE1")

# %%
selectiondialog_plot_bcells = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_cd4t = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_cd8t = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_endothelium = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_epithelial = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_epithelium = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_fib_peri = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_ilc = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_myeloid = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

selectiondialog_plot_plasma = SelectionDialogPlot(
    title = "Selection",
    params= ["Cell states", "Disease", "Inflammation", "Patient", "Sample ID", "Site", "Treatment"],
    size=[200, 500],
    position=[420, 10]
)

# %%
violin_plot_bcells_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_cd4t_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_cd8t_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_endothelium_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_epithelial_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_epithelium_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell state", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_fib_peri_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_ilc_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_myeloid_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_plasma_CD = ViolinPlot(
    title = "Gene expression in each cell state in CD",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_bcells_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_cd4t_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_cd8t_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_endothelium_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_epithelial_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_epithelium_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell state", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_fib_peri_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_ilc_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_myeloid_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

violin_plot_plasma_UC = ViolinPlot(
    title = "Gene expression in each cell state in UC",
    params = ["Cell states", "Gene Expression"],
    size=[450, 350],
    position=[10, 10]
)

# %%
box_plot_bcells_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_cd4t_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_cd8t_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_endothelium_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_epithelial_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_epithelium_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell state", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_fib_peri_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_ilc_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_myeloid_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_plasma_CD = BoxPlot(
    title = "Percent of gene expression in each cell state in CD",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_bcells_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_cd4t_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_cd8t_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_endothelium_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_epithelial_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_epithelium_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell state", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_fib_peri_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_ilc_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_myeloid_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

box_plot_plasma_UC = BoxPlot(
    title = "Percent of gene expression in each cell state in UC",
    params = ["Cell states", "Proportion"],
    size=[450, 350],
    position=[10, 10]
)

# %%
selectiondialog_plot_genes_bcells_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_cd4t_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_cd8t_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_endothelium_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelial_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelium_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_fib_peri_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_ilc_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_myeloid_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_plasma_CD = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_bcells_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_cd4t_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_cd8t_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_endothelium_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelial_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelium_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_fib_peri_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_ilc_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_myeloid_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

selectiondialog_plot_genes_plasma_UC = SelectionDialogPlot(
    title = "Selection",
    params= ["Gene", "Gene Expression"],
    size=[300, 240],
    position=[10, 370]
)

# %%
selectiondialog_plot_genes_bcells_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_cd4t_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_cd8t_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_endothelium_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelial_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelium_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_fib_peri_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_ilc_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_myeloid_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_plasma_CD_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_bcells_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_cd4t_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_cd8t_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_endothelium_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelial_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_epithelium_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_fib_peri_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_ilc_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_myeloid_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

selectiondialog_plot_genes_plasma_UC_proportion = SelectionDialogPlot(
    title = "Gene selection",
    params= ["Gene"],
    size=[300, 120],
    position=[10, 370]
)

# %%
from mdvtools.charts.box_plot import BoxPlot

box_plot_bcells = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_cd4t = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_cd8t = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_endothelium = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_epithelial = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_epithelium = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_fib_peri = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_ilc = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_myeloid = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

box_plot_plasma = BoxPlot(
    title = "Percent of each patient's cells",
    params = ["Cell states", "Proportion"],
    size=[620, 350],
    position=[10, 10]
)

# %%
# converting the chart implementation outputs to JSON and setting up the project view
list_charts_bcell = []
list_charts_bcell_genes = []
list_charts_bcell_abundance = []
list_charts_bcell_genes_expression_CD = []
list_charts_bcell_genes_expression_UC = []
list_charts_bcell_genes_expression_CD_proportion = []
list_charts_bcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_cd4tcell = []
list_charts_cd4tcell_genes = []
list_charts_cd4tcell_abundance = []
list_charts_cd4tcell_genes_expression_CD = []
list_charts_cd4tcell_genes_expression_UC = []
list_charts_cd4tcell_genes_expression_CD_proportion = []
list_charts_cd4tcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_cd8tcell = []
list_charts_cd8tcell_genes = []
list_charts_cd8tcell_abundance = []
list_charts_cd8tcell_genes_expression_CD = []
list_charts_cd8tcell_genes_expression_UC = []
list_charts_cd8tcell_genes_expression_CD_proportion = []
list_charts_cd8tcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_endotheliumcell = []
list_charts_endotheliumcell_genes = []
list_charts_endotheliumcell_abundance = []
list_charts_endotheliumcell_genes_expression_CD = []
list_charts_endotheliumcell_genes_expression_UC = []
list_charts_endotheliumcell_genes_expression_CD_proportion = []
list_charts_endotheliumcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_epithelialcell = []
list_charts_epithelialcell_genes = []
list_charts_epithelialcell_abundance = []
list_charts_epithelialcell_genes_expression_CD = []
list_charts_epithelialcell_genes_expression_UC = []
list_charts_epithelialcell_genes_expression_CD_proportion = []
list_charts_epithelialcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_epitheliumcell = []
list_charts_epitheliumcell_genes = []
list_charts_epitheliumcell_abundance = []
list_charts_epitheliumcell_genes_expression_CD = []
list_charts_epitheliumcell_genes_expression_UC = []
list_charts_epitheliumcell_genes_expression_CD_proportion = []
list_charts_epitheliumcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_fibpericell = []
list_charts_fibpericell_genes = []
list_charts_fibpericell_abundance = []
list_charts_fibpericell_genes_expression_CD = []
list_charts_fibpericell_genes_expression_UC = []
list_charts_fibpericell_genes_expression_CD_proportion = []
list_charts_fibpericell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_ilccell = []
list_charts_ilccell_genes = []
list_charts_ilccell_abundance = []
list_charts_ilccell_genes_expression_CD = []
list_charts_ilccell_genes_expression_UC = []
list_charts_ilccell_genes_expression_CD_proportion = []
list_charts_ilccell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_myeloidcell = []
list_charts_myeloidcell_genes = []
list_charts_myeloidcell_abundance = []
list_charts_myeloidcell_genes_expression_CD = []
list_charts_myeloidcell_genes_expression_UC = []
list_charts_myeloidcell_genes_expression_CD_proportion = []
list_charts_myeloidcell_genes_expression_UC_proportion = []
# * * * * * * 
list_charts_plasmacell = []
list_charts_plasmacell_genes = []
list_charts_plasmacell_abundance = []
list_charts_plasmacell_genes_expression_CD = []
list_charts_plasmacell_genes_expression_UC = []
list_charts_plasmacell_genes_expression_CD_proportion = []
list_charts_plasmacell_genes_expression_UC_proportion = []


# cells panel
list_charts_bcell.append(scatter2D_plot_bcells.plot_data)
list_charts_bcell_genes.append(scatter2D_plot_bcells_genes.plot_data)
list_charts_bcell_genes.append(selectiondialog_plot_bcells.plot_data)
list_charts_bcell_abundance.append(box_plot_bcells.plot_data)
list_charts_bcell_genes_expression_CD.append(violin_plot_bcells_CD.plot_data)
list_charts_bcell_genes_expression_UC.append(violin_plot_bcells_UC.plot_data)
list_charts_bcell_genes_expression_CD.append(selectiondialog_plot_genes_bcells_CD.plot_data)
list_charts_bcell_genes_expression_UC.append(selectiondialog_plot_genes_bcells_UC.plot_data)
list_charts_bcell_genes_expression_CD_proportion.append(box_plot_bcells_CD.plot_data)
list_charts_bcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_bcells_CD_proportion.plot_data)
list_charts_bcell_genes_expression_UC_proportion.append(box_plot_bcells_UC.plot_data)
list_charts_bcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_bcells_UC_proportion.plot_data)
# * * * * * * 
list_charts_cd4tcell.append(scatter2D_plot_cd4t.plot_data)
list_charts_cd4tcell_genes.append(scatter2D_plot_cd4t_genes.plot_data)
list_charts_cd4tcell_genes.append(selectiondialog_plot_cd4t.plot_data)
list_charts_cd4tcell_abundance.append(box_plot_cd4t.plot_data)
list_charts_cd4tcell_genes_expression_CD.append(violin_plot_cd4t_CD.plot_data)
list_charts_cd4tcell_genes_expression_UC.append(violin_plot_cd4t_UC.plot_data)
list_charts_cd4tcell_genes_expression_CD.append(selectiondialog_plot_genes_cd4t_CD.plot_data)
list_charts_cd4tcell_genes_expression_UC.append(selectiondialog_plot_genes_cd4t_UC.plot_data)
list_charts_cd4tcell_genes_expression_CD_proportion.append(box_plot_cd4t_CD.plot_data)
list_charts_cd4tcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_cd4t_CD_proportion.plot_data)
list_charts_cd4tcell_genes_expression_UC_proportion.append(box_plot_cd4t_UC.plot_data)
list_charts_cd4tcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_cd4t_UC_proportion.plot_data)
# * * * * * * 
list_charts_cd8tcell.append(scatter2D_plot_cd8t.plot_data)
list_charts_cd8tcell_genes.append(scatter2D_plot_cd8t_genes.plot_data)
list_charts_cd8tcell_genes.append(selectiondialog_plot_cd8t.plot_data)
list_charts_cd8tcell_abundance.append(box_plot_cd8t.plot_data)
list_charts_cd8tcell_genes_expression_CD.append(violin_plot_cd8t_CD.plot_data)
list_charts_cd8tcell_genes_expression_UC.append(violin_plot_cd8t_UC.plot_data)
list_charts_cd8tcell_genes_expression_CD.append(selectiondialog_plot_genes_cd8t_CD.plot_data)
list_charts_cd8tcell_genes_expression_UC.append(selectiondialog_plot_genes_cd8t_UC.plot_data)
list_charts_cd8tcell_genes_expression_CD_proportion.append(box_plot_cd8t_CD.plot_data)
list_charts_cd8tcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_cd8t_CD_proportion.plot_data)
list_charts_cd8tcell_genes_expression_UC_proportion.append(box_plot_cd8t_UC.plot_data)
list_charts_cd8tcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_cd8t_UC_proportion.plot_data)
# * * * * * * 
list_charts_endotheliumcell.append(scatter2D_plot_endothelium.plot_data)
list_charts_endotheliumcell_genes.append(scatter2D_plot_endothelium_genes.plot_data)
list_charts_endotheliumcell_genes.append(selectiondialog_plot_endothelium.plot_data)
list_charts_endotheliumcell_abundance.append(box_plot_endothelium.plot_data)
list_charts_endotheliumcell_genes_expression_CD.append(violin_plot_endothelium_CD.plot_data)
list_charts_endotheliumcell_genes_expression_UC.append(violin_plot_endothelium_UC.plot_data)
list_charts_endotheliumcell_genes_expression_CD.append(selectiondialog_plot_genes_endothelium_CD.plot_data)
list_charts_endotheliumcell_genes_expression_UC.append(selectiondialog_plot_genes_endothelium_UC.plot_data)
list_charts_endotheliumcell_genes_expression_CD_proportion.append(box_plot_endothelium_CD.plot_data)
list_charts_endotheliumcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_endothelium_CD_proportion.plot_data)
list_charts_endotheliumcell_genes_expression_UC_proportion.append(box_plot_endothelium_UC.plot_data)
list_charts_endotheliumcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_endothelium_UC_proportion.plot_data)
# * * * * * * 
list_charts_epithelialcell.append(scatter2D_plot_epithelial.plot_data)
list_charts_epithelialcell_genes.append(scatter2D_plot_epithelial_genes.plot_data)
list_charts_epithelialcell_genes.append(selectiondialog_plot_epithelial.plot_data)
list_charts_epithelialcell_abundance.append(box_plot_epithelial.plot_data)
list_charts_epithelialcell_genes_expression_CD.append(violin_plot_epithelial_CD.plot_data)
list_charts_epithelialcell_genes_expression_UC.append(violin_plot_epithelial_UC.plot_data)
list_charts_epithelialcell_genes_expression_CD.append(selectiondialog_plot_genes_epithelial_CD.plot_data)
list_charts_epithelialcell_genes_expression_UC.append(selectiondialog_plot_genes_epithelial_UC.plot_data)
list_charts_epithelialcell_genes_expression_CD_proportion.append(box_plot_epithelial_CD.plot_data)
list_charts_epithelialcell_genes_expression_UC_proportion.append(box_plot_epithelial_UC.plot_data)
list_charts_epithelialcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_epithelial_CD_proportion.plot_data)
list_charts_epithelialcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_epithelial_UC_proportion.plot_data)
# * * * * * * 
list_charts_epitheliumcell.append(scatter2D_plot_epithelium.plot_data)
list_charts_epitheliumcell_genes.append(scatter2D_plot_epithelium_genes.plot_data)
list_charts_epitheliumcell_genes.append(selectiondialog_plot_epithelium.plot_data)
list_charts_epitheliumcell_abundance.append(box_plot_epithelium.plot_data)
list_charts_epitheliumcell_genes_expression_CD.append(violin_plot_epithelium_CD.plot_data)
list_charts_epitheliumcell_genes_expression_CD.append(selectiondialog_plot_genes_epithelium_CD.plot_data)
list_charts_epitheliumcell_genes_expression_UC.append(violin_plot_epithelium_UC.plot_data)
list_charts_epitheliumcell_genes_expression_UC.append(selectiondialog_plot_genes_epithelium_UC.plot_data)
list_charts_epitheliumcell_genes_expression_CD_proportion.append(box_plot_epithelium_CD.plot_data)
list_charts_epitheliumcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_epithelium_CD_proportion.plot_data)
list_charts_epitheliumcell_genes_expression_UC_proportion.append(box_plot_epithelium_UC.plot_data)
list_charts_epitheliumcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_epithelium_UC_proportion.plot_data)
# * * * * * * 
list_charts_fibpericell.append(scatter2D_plot_fib_peri.plot_data)
list_charts_fibpericell_genes.append(scatter2D_plot_fib_peri_genes.plot_data)
list_charts_fibpericell_genes.append(selectiondialog_plot_fib_peri.plot_data)
list_charts_fibpericell_abundance.append(box_plot_fib_peri.plot_data)
list_charts_fibpericell_genes_expression_CD.append(violin_plot_fib_peri_CD.plot_data)
list_charts_fibpericell_genes_expression_CD.append(selectiondialog_plot_genes_fib_peri_CD.plot_data)
list_charts_fibpericell_genes_expression_UC.append(violin_plot_fib_peri_UC.plot_data)
list_charts_fibpericell_genes_expression_UC.append(selectiondialog_plot_genes_fib_peri_UC.plot_data)
list_charts_fibpericell_genes_expression_CD_proportion.append(box_plot_fib_peri_CD.plot_data)
list_charts_fibpericell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_fib_peri_CD_proportion.plot_data)
list_charts_fibpericell_genes_expression_UC_proportion.append(box_plot_fib_peri_UC.plot_data)
list_charts_fibpericell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_fib_peri_UC_proportion.plot_data)
# * * * * * * 
list_charts_ilccell.append(scatter2D_plot_ilc.plot_data)
list_charts_ilccell_genes.append(scatter2D_plot_ilc_genes.plot_data)
list_charts_ilccell_genes.append(selectiondialog_plot_ilc.plot_data)
list_charts_ilccell_abundance.append(box_plot_ilc.plot_data)
list_charts_ilccell_genes_expression_CD.append(violin_plot_ilc_CD.plot_data)
list_charts_ilccell_genes_expression_CD.append(selectiondialog_plot_genes_ilc_CD.plot_data)
list_charts_ilccell_genes_expression_UC.append(violin_plot_ilc_UC.plot_data)
list_charts_ilccell_genes_expression_UC.append(selectiondialog_plot_genes_ilc_UC.plot_data)
list_charts_ilccell_genes_expression_CD_proportion.append(box_plot_ilc_CD.plot_data)
list_charts_ilccell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_ilc_CD_proportion.plot_data)
list_charts_ilccell_genes_expression_UC_proportion.append(box_plot_ilc_UC.plot_data)
list_charts_ilccell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_ilc_UC_proportion.plot_data)
# * * * * * * 
list_charts_myeloidcell.append(scatter2D_plot_myeloid.plot_data)
list_charts_myeloidcell_genes.append(scatter2D_plot_myeloid_genes.plot_data)
list_charts_myeloidcell_genes.append(selectiondialog_plot_myeloid.plot_data)
list_charts_myeloidcell_abundance.append(box_plot_myeloid.plot_data)
list_charts_myeloidcell_genes_expression_CD.append(violin_plot_myeloid_CD.plot_data)
list_charts_myeloidcell_genes_expression_CD.append(selectiondialog_plot_genes_myeloid_CD.plot_data)
list_charts_myeloidcell_genes_expression_UC.append(violin_plot_myeloid_UC.plot_data)
list_charts_myeloidcell_genes_expression_UC.append(selectiondialog_plot_genes_myeloid_UC.plot_data)
list_charts_myeloidcell_genes_expression_CD_proportion.append(box_plot_myeloid_CD.plot_data)
list_charts_myeloidcell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_myeloid_CD_proportion.plot_data)
list_charts_myeloidcell_genes_expression_UC_proportion.append(box_plot_myeloid_UC.plot_data)
list_charts_myeloidcell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_myeloid_UC_proportion.plot_data)
# * * * * * * 
list_charts_plasmacell.append(scatter2D_plot_plasma.plot_data)
list_charts_plasmacell_genes.append(scatter2D_plot_plasma_genes.plot_data)
list_charts_plasmacell_genes.append(selectiondialog_plot_plasma.plot_data)
list_charts_plasmacell_abundance.append(box_plot_plasma.plot_data)
list_charts_plasmacell_genes_expression_CD.append(violin_plot_plasma_CD.plot_data)
list_charts_plasmacell_genes_expression_CD.append(selectiondialog_plot_genes_plasma_CD.plot_data)
list_charts_plasmacell_genes_expression_UC.append(violin_plot_plasma_UC.plot_data)
list_charts_plasmacell_genes_expression_UC.append(selectiondialog_plot_genes_plasma_UC.plot_data)
list_charts_plasmacell_genes_expression_CD_proportion.append(box_plot_plasma_CD.plot_data)
list_charts_plasmacell_genes_expression_CD_proportion.append(selectiondialog_plot_genes_plasma_CD_proportion.plot_data)
list_charts_plasmacell_genes_expression_UC_proportion.append(box_plot_plasma_UC.plot_data)
list_charts_plasmacell_genes_expression_UC_proportion.append(selectiondialog_plot_genes_plasma_UC_proportion.plot_data)

# %%
# setting config

view_config = {'initialCharts': {'Summary': []}}

# * * * * * * 
view_config_bcells = {'initialCharts': {"B cells metadata 1": list_charts_bcell, "B cells metadata 2":list_charts_bcell_genes, "B cells metadata 3": list_charts_bcell_abundance}}
view_config1_bcells = {'initialCharts': {"B cells expression CD": list_charts_bcell_genes_expression_CD, "B cells expression proportion CD": list_charts_bcell_genes_expression_CD_proportion, "B cells expression UC": list_charts_bcell_genes_expression_UC, "B cells expression proportion UC": list_charts_bcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_cd4t = {'initialCharts': {"CD4+ T cells metadata 1": list_charts_cd4tcell, "CD4+ T cells metadata 2":list_charts_cd4tcell_genes, "CD4+ T cells metadata 3":list_charts_cd4tcell_abundance}}
view_config1_cd4t = {'initialCharts': {"CD4+ T cells expression CD": list_charts_cd4tcell_genes_expression_CD, "CD4+ T cells expression proportion CD": list_charts_cd4tcell_genes_expression_CD_proportion, "CD4+ T cells expression UC": list_charts_cd4tcell_genes_expression_UC, "CD4+ T cells expression proportion UC": list_charts_cd4tcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_cd8t = {'initialCharts': {"CD8+ T cells metadata 1": list_charts_cd8tcell, "CD8+ T cells metadata 2":list_charts_cd8tcell_genes, "CD8+ T cells metadata 3":list_charts_cd8tcell_abundance}}
view_config1_cd8t = {'initialCharts': {"CD8+ T cells expression CD": list_charts_cd8tcell_genes_expression_CD, "CD8+ T cells expression proportion CD": list_charts_cd8tcell_genes_expression_CD_proportion, "CD8+ T cells expression UC": list_charts_cd8tcell_genes_expression_UC, "CD8+ T cells expression proportion UC": list_charts_cd8tcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_endothelium = {'initialCharts': {"Endothelial cells metadata 1": list_charts_endotheliumcell, "Endothelial cells metadata 2":list_charts_endotheliumcell_genes, "Endothelial cells metadata 3":list_charts_endotheliumcell_abundance}}
view_config1_endothelium = {'initialCharts': {"Endothelial cells expression CD": list_charts_endotheliumcell_genes_expression_CD, "Endothelial cells expression proportion CD": list_charts_endotheliumcell_genes_expression_CD_proportion, "Endothelial cells expression UC": list_charts_endotheliumcell_genes_expression_UC, "Endothelial cells expression proportion UC": list_charts_endotheliumcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_epithelial = {'initialCharts': {"Ileal epithelial cells metadata 1": list_charts_epithelialcell, "Ileal epithelial cells metadata 2":list_charts_epithelialcell_genes, "Ileal epithelial cells metadata 3":list_charts_epithelialcell_abundance}}
view_config1_epithelial = {'initialCharts': {"Ileal epithelial cells expression CD": list_charts_epithelialcell_genes_expression_CD, "Ileal epithelial cells expression proportion CD": list_charts_epithelialcell_genes_expression_CD_proportion, "Ileal epithelial cells expression UC": list_charts_epithelialcell_genes_expression_UC, "Ileal epithelial cells expression proportion UC": list_charts_epithelialcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_epithelium = {'initialCharts': {"Colonic epithelial cells metadata 1": list_charts_epitheliumcell, "Colonic epithelial cells metadata 2":list_charts_epitheliumcell_genes, "Colonic epithelial cells metadata 3":list_charts_epitheliumcell_abundance}}
view_config1_epithelium = {'initialCharts': {"Colonic epithelial cells expression CD": list_charts_epitheliumcell_genes_expression_CD, "Colonic epithelial cells expression proportion CD": list_charts_epitheliumcell_genes_expression_CD_proportion, "Colonic epithelial cells expression UC": list_charts_epitheliumcell_genes_expression_UC, "Colonic epithelial cells expression proportion UC": list_charts_epitheliumcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_fibroblast = {'initialCharts': {"Fibroblast pericyte cells metadata 1": list_charts_fibpericell, "Fibroblast pericyte cells metadata 2":list_charts_fibpericell_genes, "Fibroblast pericyte cells metadata 3":list_charts_fibpericell_abundance}}
view_config1_fibroblast = {'initialCharts': {"Fibroblast pericyte cells expression CD": list_charts_fibpericell_genes_expression_CD, "Fibroblast pericyte cells expression proportion CD": list_charts_fibpericell_genes_expression_CD_proportion, "Fibroblast pericyte cells expression UC": list_charts_fibpericell_genes_expression_UC, "Fibroblast pericyte cells expression proportion UC": list_charts_fibpericell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_innate = {'initialCharts': {"Innate lymphoid cells metadata 1": list_charts_ilccell, "Innate lymphoid cells metadata 2":list_charts_ilccell_genes, "Innate lymphoid cells metadata 3":list_charts_ilccell_abundance}}
view_config1_innate = {'initialCharts': {"Innate lymphoid cells expression CD": list_charts_ilccell_genes_expression_CD, "Innate lymphoid cells expression proportion CD": list_charts_ilccell_genes_expression_CD_proportion, "Innate lymphoid cells expression UC": list_charts_ilccell_genes_expression_UC, "Innate lymphoid cells expression proportion UC": list_charts_ilccell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_myeloid = {'initialCharts': {"Myeloid cells metadata 1": list_charts_myeloidcell, "Myeloid cells metadata 2":list_charts_myeloidcell_genes, "Myeloid cells metadata 3":list_charts_myeloidcell_abundance}}
view_config1_myeloid = {'initialCharts': {"Myeloid cells expression CD": list_charts_myeloidcell_genes_expression_CD, "Myeloid cells expression proportion CD": list_charts_myeloidcell_genes_expression_CD_proportion, "Myeloid cells expression UC": list_charts_myeloidcell_genes_expression_UC, "Myeloid cells expression proportion UC": list_charts_myeloidcell_genes_expression_UC_proportion}}
# * * * * * * 
view_config_plasma = {'initialCharts': {"Plasma cells metadata 1": list_charts_plasmacell, "Plasma cells metadata 2":list_charts_plasmacell_genes, "Plasma cells metadata 3":list_charts_plasmacell_abundance}}
view_config1_plasma= {'initialCharts': {"Plasma cells expression CD": list_charts_plasmacell_genes_expression_CD, "Plasma cells expression proportion CD": list_charts_plasmacell_genes_expression_CD_proportion, "Plasma cells expression UC": list_charts_plasmacell_genes_expression_UC, "Plasma cells expression proportion UC": list_charts_plasmacell_genes_expression_UC_proportion}}


p.set_view("Landing page", view_config)

p.set_view("B cells", view_config_bcells)
p.set_view("CD4+ T cells", view_config_cd4t)
p.set_view("CD8+ T innate T NK cells", view_config_cd8t)
p.set_view("Colonic epithelial cells", view_config_epithelium)
p.set_view("Endothelial cells", view_config_endothelium)
p.set_view("Fibroblast pericyte cells", view_config_fibroblast)
p.set_view("Ileal epithelial cells", view_config_epithelial)
p.set_view("Innate lymphoid cells", view_config_innate)
p.set_view("Myeloid cells", view_config_myeloid)
p.set_view("Plasma cells", view_config_plasma)

p.set_view("B cells expression summary", view_config1_bcells)
p.set_view("CD4+ T cells expression summary", view_config1_cd4t)
p.set_view("CD8+ T cells expression summary", view_config1_cd8t)
p.set_view("Colonic epithelial cells expression summary", view_config1_epithelium)
p.set_view("Endothelial cells expression summary", view_config1_endothelium)
p.set_view("Fibroblast pericyte cells expression summary", view_config1_fibroblast)
p.set_view("Ileal epithelial cells expression summary", view_config1_epithelial)
p.set_view("Innate lymphoid cells expression summary", view_config1_innate)
p.set_view("Myeloid cells expression summary", view_config1_myeloid)
p.set_view("Plasma cells expression summary", view_config1_plasma)


p.set_editable(True)

# %%
# Converting to static project

static_path = os.path.expanduser('~/Documents/static_taurus_all_cells_MDV_1809_4/')

p.convert_to_static_page(static_path)

# %%
p.serve()
# Out:
# created Flask <Flask 'mdvtools.server'>
# python(68055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#  * Serving Flask app 'mdvtools.server'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5050
#  * Running on http://129.67.46.217:5050
# Press CTRL+C to quit
# 127.0.0.1 - - [18/Sep/2024 18:08:27] "GET / HTTP/1.1" 200 -
# recieved request to project_index
# 127.0.0.1 - - [18/Sep/2024 18:08:28] "GET /static/js/mdv.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Sep/2024 18:08:28] "GET /static/assets/mdv.css HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Sep/2024 18:08:28] "GET /static/assets/client-BqnbsFv0.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Sep/2024 18:08:28] "GET /static/assets/csvWorker-e8cMUEqV.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Sep/2024 18:08:28] "GET /datasources.json HTTP/1.1" 304 -
# ...
