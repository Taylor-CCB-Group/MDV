# %% [markdown]
# # Processing, Clustering and Visualising in MDV the TAURUS data

# %% [markdown]
# #### Importing the required packages for data preprocessing

# %%
import pandas as pd

# %% [markdown]
# #### Importing the required packages for MDV set up and visualisation

# %%
import os
from mdvtools.mdvproject import MDVProject
from mdvtools.charts.dot_plot import DotPlot
from mdvtools.charts.scatter_plot_3D import ScatterPlot3D
from mdvtools.charts.table_plot import TablePlot
from mdvtools.charts.selection_dialog_plot import SelectionDialogPlot

# %% [markdown]
# ## Data analysis section

# %%
spot_data = pd.read_csv('../../../../../Documents/spot_dataset_a/spot_dataset_a/feature_table_umap.csv')

# %%
spot_data = spot_data.set_index('unique_object_ids')

# %%
organoids_data = spot_data.iloc[:, :2]
features_data = spot_data.iloc[:, 2:]

# %%
organoids_data = organoids_data.reset_index()
features_data = features_data.reset_index()

# %%
organoids_data["timepoint_cat"] = "timepoint_" + organoids_data["timepoint"].astype("str")

# %%
features_data_try = spot_data.iloc[:, 2:].T
features_data_try.index.name = 'feature_id'
features_data_try.reset_index(inplace=True)

# %%
dot_plot = DotPlot(
    title= "Percent of gene expression per cell state",
    params = ["condition", {"linkedDsName":"features","maxItems":4,"type":"RowsAsColsQuery"}], 
    size=[700, 300],
    position=[10, 470]
)

# configuring the dot plot
dot_plot.set_axis_properties("x", {"label": "", "textSize": 13, "tickfont": 10})
dot_plot.set_axis_properties("y", {"label": "", "textSize": 13, "tickfont": 10})
dot_plot.set_axis_properties("ry", {"label": "", "textSize": 13, "tickfont": 10})
dot_plot.set_color_scale(log_scale=False)
dot_plot.set_color_legend(True, [40, 10])
dot_plot.set_fraction_legend(True, [0, 0])

feature1 = "UMAP1"
feature2 = "UMAP2"
feature3 = "UMAP3"

# creating a scatter plot
scatter_plot_1 = ScatterPlot3D(
    title=f"{feature1} x {feature2} x {feature3}",
    params=#["angular_second_moment", {"linkedDsName":"features","maxItems":4,"type":"RowsAsColsQuery"}],
    [f"Link|{feature1}(Link)|{features_data_try[features_data_try.feature_id == (feature1)].index[0]}", f"Link|{feature2}(Link)|{features_data_try[features_data_try.feature_id == (feature2)].index[0]}", f"Link|{feature3}(Link)|{features_data_try[features_data_try.feature_id == (feature3)].index[0]}"],
    size=[450, 450],
    position=[10, 10],
    default_color="#377eb8",
    brush="poly",
    #on_filter="hide",
    radius=5,
    opacity=0.8,
    center = [10.226573467254639, 11.17284369468689, 5.338449418544769],
    camera={"distance": 50, "theta": 0.5, "phi": 0.5}
)

# configuring the scatter plot
scatter_plot_1.set_color_by("condition")



# creating a scatter plot
scatter_plot_2 = ScatterPlot3D(
    title=f"{feature1} x {feature2} x {feature3}",
    params=#["angular_second_moment", {"linkedDsName":"features","maxItems":4,"type":"RowsAsColsQuery"}],
    [f"Link|{feature1}(Link)|{features_data_try[features_data_try.feature_id == (feature1)].index[0]}", f"Link|{feature2}(Link)|{features_data_try[features_data_try.feature_id == (feature2)].index[0]}", f"Link|{feature3}(Link)|{features_data_try[features_data_try.feature_id == (feature3)].index[0]}"],
    size=[450, 450],
    position=[470, 10],
    default_color="#377eb8",
    brush="poly",
    #on_filter="hide",
    radius=5,
    opacity=0.8,
    center = [10.226573467254639, 11.17284369468689, 5.338449418544769],
    camera={"distance": 50, "theta": 0.5, "phi": 0.5}
)

# configuring the scatter plot
scatter_plot_2.set_color_by("timepoint")




# creating a scatter plot
scatter_plot_3 = ScatterPlot3D(
    title=f"{feature1} x {feature2} x {feature3}",
    params=#["angular_second_moment", {"linkedDsName":"features","maxItems":4,"type":"RowsAsColsQuery"}],
    [f"Link|{feature1}(Link)|{features_data_try[features_data_try.feature_id == (feature1)].index[0]}", f"Link|{feature2}(Link)|{features_data_try[features_data_try.feature_id == (feature2)].index[0]}", f"Link|{feature3}(Link)|{features_data_try[features_data_try.feature_id == (feature3)].index[0]}"],
    size=[450, 450],
    position=[930, 10],
    default_color="#377eb8",
    brush="poly",
    #on_filter="hide",
    radius=5,
    opacity=0.8,
    center = [10.226573467254639, 11.17284369468689, 5.338449418544769],
    camera={"distance": 50, "theta": 0.5, "phi": 0.5}
)

# configuring the scatter plot
scatter_plot_3.set_color_by("unique_object_ids")



# creating a table plot
table = TablePlot(
    title="Parameters",
    params=["feature_id"],
    size=[200, 500],
    position=[10, 10]
)

# creating a table plot
selection_dialog = SelectionDialogPlot(
    title="Filtering",
    params=["condition", "timepoint", "unique_object_ids"],
    size=[200, 400],
    position=[10, 500]
)

# %%
#features_data_try.loc[features_data_try.feature_id == "min_curvature"]
features_data_try[features_data_try.feature_id == "min_curvature"].index[0]
# Out:
# 0

# %%
features_data_try.iloc[:,:1]
# Out:
# unique_object_ids                        feature_id
# 0                                     min_curvature
# 1                                     std_curvature
# 2                             max_centroid_distance
# 3                            mean_centroid_distance
# 4                  std_mean_centroid_distance_ratio
# ..                                              ...
# 232                                     div_sift_93
# 233                                     div_sift_94
# 234                                           UMAP1
# 235                                           UMAP2
_4', 'shape_low_organoid_35_29_5', 'shape_low_organoid_35_29_6', 'shape_low_organoid_35_29_7', 'shape_low_organoid_35_29_8', 'shape_low_organoid_35_29_9', 'shape_low_organoid_36_30_0', 'shape_low_organoid_36_30_1', 'shape_low_organoid_36_30_10', 'shape_low_organoid_36_30_3', 'shape_low_organoid_36_30_5', 'shape_low_organoid_38_32_10', 'shape_low_organoid_37_31_21', 'shape_low_organoid_37_31_23', 'shape_low_organoid_37_31_24', 'shape_low_organoid_37_31_25', 'shape_low_organoid_37_31_26', 'shape_low_organoid_37_31_27', 'shape_low_organoid_37_31_28', 'shape_low_organoid_37_31_3', 'shape_low_organoid_37_31_4', 'shape_low_organoid ...
# Updated datasource metadata
# In set_view
# default
# In MDVProject.add_datasource: Added datasource successfully 'data_organoids'
# starting add_datasource
# is ds None? None
# got passed the ds check
# data_organoids
# created h5 group without error
# - adding column 'feature_id' to datasource 'features'
#  - non-dodgy columns: [{'datatype': 'text', 'name': 'feature_id', 'field': 'feature_id', 'values': ['min_curvature', 'sift_motion_6', 'stddev_divergence_global_flow', 'hist_bin_4_region_001', 'stddev_speed_flow_region1', 'hist_bin_4_region_002', 'hist_bin_5_region_002', 'mean_speed_flow_region_2', 'stddev_speed_flow_region2', 'hist_bin_2_region_003', 'hist_bin_3_region_003', 'mean_speed_flow_region_3', 'stddev_speed_flow_region3', 'sift_motion_4', 'sift_motion_11', 'mean_speed_global_flow', 'sift_motion_16', 'sift_motion_18', 'sift_motion_22', 'sift_motion_31', 'sift_motion_33', 'sift_motion_42', 'sift_motion_43', 'sift_motion_48', 'sift_motion_54', 'sift_motion_55', 'sift_motion_68', 'sift_motion_69', 'stddev_curl_global_flow', 'mean_speed_global', 'sift_appear_69', 'sift_appear_96', 'sift_appear_71', 'sift_appear_73', 'sift_appear_74', 'sift_appear_79', 'sift_appear_80', 'sift_appear_82', 'sift_appear_83', 'sift_appear_86', 'sift_appear_87', 'sift_appear_89', 'sift_appear_91', 'sift_appear_95', 'sift_appear_97', 'sift_appear_128', 'sift_appear_99', 'sift_appear_101', 'sift_appear_106', 'sift_appear_107', 'sift_appear_108', 'sift_appear_111', 'sift_appear_114', 'sift_appear_116', 'sift_appear_121', 'sift_appear_122', 'sift_appear_123', 'sift_appear_124', 'sift_motion_82', 'sift_motion_86', 'sift_motion_89', 'div_sift_49', 'curl_sift_116', 'curl_sift_117', 'curl_sift_120', 'div_sift_4', 'div_sift_8', 'div_sift_11', 'div_sift_14', 'div_sift_16', 'div_sift_17', 'div_sift_20', 'div_sift_37', 'div_sift_45', 'div_sift_52', 'sift_motion_102', 'div_sift_56', 'div_sift_69', 'div_sift_71', 'div_sift_77', 'div_sift_79', 'div_sift_81', 'div_sift_84', 'div_sift_89', 'div_sift_93', 'div_sift_94', 'UMAP1', 'UMAP2', 'curl_sift_115', 'curl_sift_113', 'curl_sift_112', 'curl_sift_109', 'sift_motion_110', 'sift_motion_119', 'sift_motion_120', 'sift_motion_122', 'sift_motion_124', 'curl_sift_4', 'curl_sift_8', 'curl_sift_11', 'curl_sift_16', 'curl_sift_29', 'curl_sift_41', 'curl_sift_48', 'curl_sift_51', 'curl_sift_52', 'curl_sift_53', 'curl_sift_57', 'curl_sift_62', 'curl_sift_64', 'curl_sift_68', 'curl_sift_69', 'curl_sift_70', 'curl_sift_78', 'curl_sift_84', 'curl_sift_86', 'curl_sift_101', 'sift_appear_70', 'sift_appear_66', 'std_curvature', 'Fourier_35', 'zernike_moments_10', 'zernike_moments_11', 'zernike_moments_12', 'zernike_moments_13', 'zernike_moments_22', 'Fourier_1', 'Fourier_2', 'Fourier_3', 'Fourier_4', 'Fourier_6', 'Fourier_8', 'Fourier_15', 'Shape_Context_57', 'zernike_moments_7', 'Shape_Context_76', 'Shape_Context_86', 'Shape_Context_91', 'Shape_Context_98', 'Shape_Context_104', 'Shape_Context_113', 'Shape_Context_114', 'Shape_Context_118', 'Shape_Context_152', 'Shape_Context_157', 'Shape_Context_158', 'Shape_Context_178', 'zernike_moments_8', 'zernike_moments_6', 'sift_appear_65', 'perimeter', 'max_centroid_distance', 'mean_centroid_distance', 'std_mean_centroid_distance_ratio', 'max_chordal_distance', 'max_min_centroid_distance_ratio', 'chordal_hist_bin_2', 'chordal_hist_bin_3', 'chordal_hist_bin_4', 'chordal_hist_bin_5', 'chordal_hist_bin_6', 'chordal_hist_bin_7', 'chordal_hist_bin_8', 'equivalent_diameter', 'zernike_moments_5', 'major_axis_length', 'minor_axis_length', 'area_perim_aspect_ratio', 'major_minor_axis_ratio', 'moment_eccentricity', 'hu_moments_1', 'hu_moments_2', 'hu_moments_3', 'hu_moments_4', 'zernike_moments_2', 'zernike_moments_3', 'zernike_moments_4', 'Shape_Context_212', 'Shape_Context_213', 'Shape_Context_217', 'sift_appear_34', 'sift_appear_13', 'sift_appear_15', 'sift_appear_16', 'sift_appear_18', 'sift_appear_20', 'sift_appear_21', 'sift_appear_24', 'sift_appear_26', 'sift_appear_27', 'sift_appear_28', 'sift_appear_31', 'sift_appear_32', 'sift_appear_35', 'Shape_Context_221', 'sift_appear_38', 'sift_appear_39', 'sift_appear_40', 'sift_appear_44', 'sift_appear_47', 'sift_appear_48', 'sift_appear_52', 'sift_appear_54', 'sift_appear_55', 'sift_appear_58', 'sift_appear_59', 'sift_appear_63', 'sift_appear_12 ...
# --- setting datasource metadata: {'name': 'features', 'columns': [{'datatype': 'text', 'name': 'feature_id', 'field': 'feature_id', 'values': ['min_curvature', 'sift_motion_6', 'stddev_divergence_global_flow', 'hist_bin_4_region_001', 'stddev_speed_flow_region1', 'hist_bin_4_region_002', 'hist_bin_5_region_002', 'mean_speed_flow_region_2', 'stddev_speed_flow_region2', 'hist_bin_2_region_003', 'hist_bin_3_region_003', 'mean_speed_flow_region_3', 'stddev_speed_flow_region3', 'sift_motion_4', 'sift_motion_11', 'mean_speed_global_flow', 'sift_motion_16', 'sift_motion_18', 'sift_motion_22', 'sift_motion_31', 'sift_motion_33', 'sift_motion_42', 'sift_motion_43', 'sift_motion_48', 'sift_motion_54', 'sift_motion_55', 'sift_motion_68', 'sift_motion_69', 'stddev_curl_global_flow', 'mean_speed_global', 'sift_appear_69', 'sift_appear_96', 'sift_appear_71', 'sift_appear_73', 'sift_appear_74', 'sift_appear_79', 'sift_appear_80', 'sift_appear_82', 'sift_appear_83', 'sift_appear_86', 'sift_appear_87', 'sift_appear_89', 'sift_appear_91', 'sift_appear_95', 'sift_appear_97', 'sift_appear_128', 'sift_appear_99', 'sift_appear_101', 'sift_appear_106', 'sift_appear_107', 'sift_appear_108', 'sift_appear_111', 'sift_appear_114', 'sift_appear_116', 'sift_appear_121', 'sift_appear_122', 'sift_appear_123', 'sift_appear_124', 'sift_motion_82', 'sift_motion_86', 'sift_motion_89', 'div_sift_49', 'curl_sift_116', 'curl_sift_117', 'curl_sift_120', 'div_sift_4', 'div_sift_8', 'div_sift_11', 'div_sift_14', 'div_sift_16', 'div_sift_17', 'div_sift_20', 'div_sift_37', 'div_sift_45', 'div_sift_52', 'sift_motion_102', 'div_sift_56', 'div_sift_69', 'div_sift_71', 'div_sift_77', 'div_sift_79', 'div_sift_81', 'div_sift_84', 'div_sift_89', 'div_sift_93', 'div_sift_94', 'UMAP1', 'UMAP2', 'curl_sift_115', 'curl_sift_113', 'curl_sift_112', 'curl_sift_109', 'sift_motion_110', 'sift_motion_119', 'sift_motion_120', 'sift_motion_122', 'sift_motion_124', 'curl_sift_4', 'curl_sift_8', 'curl_sift_11', 'curl_sift_16', 'curl_sift_29', 'curl_sift_41', 'curl_sift_48', 'curl_sift_51', 'curl_sift_52', 'curl_sift_53', 'curl_sift_57', 'curl_sift_62', 'curl_sift_64', 'curl_sift_68', 'curl_sift_69', 'curl_sift_70', 'curl_sift_78', 'curl_sift_84', 'curl_sift_86', 'curl_sift_101', 'sift_appear_70', 'sift_appear_66', 'std_curvature', 'Fourier_35', 'zernike_moments_10', 'zernike_moments_11', 'zernike_moments_12', 'zernike_moments_13', 'zernike_moments_22', 'Fourier_1', 'Fourier_2', 'Fourier_3', 'Fourier_4', 'Fourier_6', 'Fourier_8', 'Fourier_15', 'Shape_Context_57', 'zernike_moments_7', 'Shape_Context_76', 'Shape_Context_86', 'Shape_Context_91', 'Shape_Context_98', 'Shape_Context_104', 'Shape_Context_113', 'Shape_Context_114', 'Shape_Context_118', 'Shape_Context_152', 'Shape_Context_157', 'Shape_Context_158', 'Shape_Context_178', 'zernike_moments_8', 'zernike_moments_6', 'sift_appear_65', 'perimeter', 'max_centroid_distance', 'mean_centroid_distance', 'std_mean_centroid_distance_ratio', 'max_chordal_distance', 'max_min_centroid_distance_ratio', 'chordal_hist_bin_2', 'chordal_hist_bin_3', 'chordal_hist_bin_4', 'chordal_hist_bin_5', 'chordal_hist_bin_6', 'chordal_hist_bin_7', 'chordal_hist_bin_8', 'equivalent_diameter', 'zernike_moments_5', 'major_axis_length', 'minor_axis_length', 'area_perim_aspect_ratio', 'major_minor_axis_ratio', 'moment_eccentricity', 'hu_moments_1', 'hu_moments_2', 'hu_moments_3', 'hu_moments_4', 'zernike_moments_2', 'zernike_moments_3', 'zernike_moments_4', 'Shape_Context_212', 'Shape_Context_213', 'Shape_Context_217', 'sift_appear_34', 'sift_appear_13', 'sift_appear_15', 'sift_appear_16', 'sift_appear_18', 'sift_appear_20', 'sift_appear_21', 'sift_appear_24', 'sift_appear_26', 'sift_appear_27', 'sift_appear_28', 'sift_appear_31', 'sift_appear_32', 'sift_appear_35', 'Shape_Context_221', 'sift_appear_38', 'sift_appear_39', 'sift_appear_40', 'sift_appear_44', 'sift_appear_47', 'sift_appear_48', 'sift_appear_52', 'sift_appear_54', 'sift_appear_55', 'sift_appear_58', 'sift_ap ...
# Updated datasource metadata
# In set_view
# default
# In MDVProject.add_datasource: Added datasource successfully 'features'
# []

# %%
numeric_data = features_data.T.iloc[1:, :].apply(pd.to_numeric, errors='coerce').values

# %%
# # creating the link between the two datasets so that selecting a subset of genes to add the expression in cells is enabled
p.add_rows_as_columns_link("data_organoids","features","feature_id","Link")
p.add_rows_as_columns_subgroup("data_organoids","features","Link",numeric_data.T) #add the gene expression

# %%
# # converting the chart implementation outputs to JSON and setting up the project view
list_charts_cells = []
list_charts_features = []


# cells panel
list_charts_cells.extend([dot_plot.plot_data, scatter_plot_1.plot_data, scatter_plot_2.plot_data, scatter_plot_3.plot_data, selection_dialog.plot_data])
list_charts_features.extend([table.plot_data])

# setting the config combining the two panels
view_config = {'initialCharts': {"data_organoids": list_charts_cells, "features": list_charts_features}}

# adding the view to the project configuration
p.set_view("default", view_config)

p.set_editable(True)
# Out:
# In set_view
# default

# %%
# serving the project
p.serve()
# Out:
# created Flask <Flask 'mdvtools.server'>
#  * Serving Flask app 'mdvtools.server'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5050
#  * Running on http://129.67.46.176:5050
# Press CTRL+C to quit
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/assets/mdv.css HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/js/mdv.js HTTP/1.1" 304 -
# recieved request to project_index
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/assets/ExpandMore-U9H8ev0k.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/assets/datasourceWorker-BDVgcx14.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /datasources.json HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /views.json HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "POST /get_view HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/assets/filteredIndexWorker-CEl1713S.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/assets/filteredIndexWorker-CEl1713S.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/img/fa-solid-900.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "GET /static/img/roboto-latin-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:54] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/catColWorker-BRK20MZB.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/img/roboto-latin-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/catWorker-D5lhlpxE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/catWorker-D5lhlpxE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:43:55] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:35] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:38] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:39] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:39] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:40] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:41] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:42] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:43] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [26/Feb/2025 15:47:44] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -

# %%
# setting up and serving the MDV project
base = os.path.expanduser('~/mdv')
project_path = os.path.join(base, 'spot') # defining the location where the project metadata will be stored
p = MDVProject(os.path.expanduser(project_path), delete_existing=False)

p.serve()
