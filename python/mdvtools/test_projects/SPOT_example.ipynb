# %% [markdown]
# # Processing, Clustering and Visualising in MDV the TAURUS data

# %% [markdown]
# #### Importing the required packages for data preprocessing

# %%
import pandas as pd

# %% [markdown]
# #### Importing the required packages for MDV set up and visualisation

# %%
import os
from mdvtools.mdvproject import MDVProject
from mdvtools.charts.dot_plot import DotPlot
from mdvtools.charts.scatter_plot_3D import ScatterPlot3D
from mdvtools.charts.box_plot import BoxPlot
from mdvtools.charts.stacked_row_plot import StackedRowChart
from mdvtools.charts.table_plot import TablePlot
from mdvtools.charts.selection_dialog_plot import SelectionDialogPlot

# %% [markdown]
# ## Data analysis section

# %%
spot_data = pd.read_csv('../../../../../Documents/spot_dataset_a/feature_table_umap_cluster.csv')

# %%
spot_trajectories = pd.read_csv('../../../../../Documents/spot_dataset_a/unique_trajectories.csv')

# %%
spot_data = spot_data.set_index('unique_object_ids')

# %%
organoids_data = spot_data.iloc[:, :2]
features_data = spot_data.iloc[:, 2:]

# %%
#organoids_data = pd.concat([organoids_data, pd.DataFrame(spot_data.iloc[:, -1])], axis=1)

# %%
organoids_data
# Out:
#                                    condition  timepoint
# unique_object_ids
# shape_high_organoid_0_0_0         shape_high          0
# shape_high_organoid_0_0_1         shape_high          1
# shape_high_organoid_0_0_10        shape_high         10
# shape_high_organoid_0_0_11        shape_high         11
# shape_high_organoid_0_0_12        shape_high         12
# ...                                      ...        ...
# base_organoid_organoid_9_47_5  base_organoid          5
# base_organoid_organoid_9_47_6  base_organoid          6
# base_organoid_organoid_9_47_7  base_organoid          7
# base_organoid_organoid_9_47_8  base_organoid          8
# base_organoid_organoid_9_47_9  base_organoid          9
#
# [9744 rows x 2 columns]

# %%
spot_trajectories["trajectory_id"] = "trajectory_" + spot_trajectories.index.astype("str")
spot_trajectories.set_index('trajectory_id', inplace=True)

organoids_trajectories = spot_trajectories.iloc[:, :2]
features_trajectories = spot_trajectories.iloc[:, 2:]

# %%
organoids_data = organoids_data.reset_index()
features_data = features_data.reset_index()

organoids_trajectories = organoids_trajectories.reset_index()
features_trajectories = features_trajectories.reset_index()

# %%
organoids_data["timepoint_cat"] = "timepoint_" + organoids_data["timepoint"].astype("str").str.zfill(2)
#organoids_data["cluster_label"] = organoids_data["cluster_label"].astype("str")
organoids_trajectories["timepoint_cat"] = "timepoint_" + organoids_trajectories["time_bin"].astype("str").str.zfill(2)

# %%
organoids_data
# Out:
#                   unique_object_ids      condition  timepoint timepoint_cat
# 0         shape_high_organoid_0_0_0     shape_high          0  timepoint_00
# 1         shape_high_organoid_0_0_1     shape_high          1  timepoint_01
# 2        shape_high_organoid_0_0_10     shape_high         10  timepoint_10
# 3        shape_high_organoid_0_0_11     shape_high         11  timepoint_11
# 4        shape_high_organoid_0_0_12     shape_high         12  timepoint_12
# ...                             ...            ...        ...           ...
# 9739  base_organoid_organoid_9_47_5  base_organoid          5  timepoint_05
# 9740  base_organoid_organoid_9_47_6  base_organoid          6  timepoint_06
# 9741  base_organoid_organoid_9_47_7  base_organoid          7  timepoint_07
# 9742  base_organoid_organoid_9_47_8  base_organoid          8  timepoint_08
# 9743  base_organoid_organoid_9_47_9  base_organoid          9  timepoint_09
#
# [9744 rows x 4 columns]

# %%
# extract the number, cast to int
organoids_data['tp_num'] = organoids_data['timepoint_cat'].str.split('_').str[-1].astype(int)

# sort by that numeric column
organoids_data = organoids_data.sort_values('tp_num').drop(columns='tp_num')

# %%
organoids_trajectories.rename(columns={"trajectory_id": "unique_object_ids", "time_bin" :"timepoint"}, inplace=True)

#organoids_data = pd.concat([organoids_data, organoids_trajectories])

# %%
#organoids_data['cluster_label'] = organoids_data['cluster_label'].fillna(0.0)

# %%
organoids_data
# Out:
#                      unique_object_ids        condition  timepoint  \
# 0            shape_high_organoid_0_0_0       shape_high          0
# 8758    base_organoid_organoid_22_15_0    base_organoid          0
# 6235        shape_low_organoid_30_24_0        shape_low          0
# 6206         shape_low_organoid_2_12_0        shape_low          0
# 3886   appearance_low_organoid_44_39_0   appearance_low          0
# ...                                ...              ...        ...
# 1558  appearance_high_organoid_14_6_28  appearance_high         28
# 6633       shape_low_organoid_42_37_28        shape_low         28
# 6662       shape_low_organoid_43_38_28        shape_low         28
# 6459       shape_low_organoid_37_31_28        shape_low         28
# 1616  appearance_high_organoid_16_8_28  appearance_high         28
#
#      timepoint_cat
# 0     timepoint_00
# 8758  timepoint_00
# 6235  timepoint_00
# 6206  timepoint_00
# 3886  timepoint_00
# ...            ...
# 1558  timepoint_28
# 6633  timepoint_28
# 6662  timepoint_28
# 6459  timepoint_28
# 1616  timepoint_28
#
# [9744 rows x 4 columns]

# %%
features_trajectories
features_trajectories.rename(columns={"trajectory_id": "unique_object_ids", "UMAP1": "UMAP1_trajectory", "UMAP2": "UMAP2_trajectory", "UMAP3": "UMAP3_trajectory"}, inplace=True)
spot_trajectories.rename(columns={"trajectory_id": "unique_object_ids", "UMAP1": "UMAP1_trajectory", "UMAP2": "UMAP2_trajectory", "UMAP3": "UMAP3_trajectory"}, inplace=True)

# %%
features_trajectories
# Out:
#     unique_object_ids  UMAP1_trajectory  UMAP2_trajectory  UMAP3_trajectory
# 0        trajectory_0         10.129061         13.208286          5.731530
# 1        trajectory_1          9.765450         13.723469          5.599437
# 2        trajectory_2          9.588668         13.879604          5.496707
# 3        trajectory_3          9.393592         14.085289          5.448748
# 4        trajectory_4          9.047018         14.313576          5.702950
# ..                ...               ...               ...               ...
# 100    trajectory_100         10.528838         10.022072          4.936020
# 101    trajectory_101         10.314974          9.731762          4.991680
# 102    trajectory_102         10.304440          9.590784          4.928095
# 103    trajectory_103         10.229068          9.527321          4.842669
# 104    trajectory_104         10.224615          9.475926          4.817468
#
# [105 rows x 4 columns]

# %%
features_trajectories_try = spot_trajectories.iloc[:, 2:].T

features_trajectories_try.index.name = 'feature_id'
features_trajectories_try.reset_index(inplace=True)

# %%
features_data_try = spot_data.iloc[:, 2:].T
features_data_try.index.name = 'feature_id'
features_data_try.reset_index(inplace=True)

# %%
#features_data_try = pd.concat([features_data_try, features_trajectories_try])

# %%
features_data_try = features_data_try.fillna(0.0)

# %%
features_data_try = features_data_try.reset_index(drop=True)
organoids_data = organoids_data.reset_index(drop=True)

# %%
features_data_try[features_data_try.feature_id == ("UMAP1")].index[0]
# Out:
# 234

# %%
features_data_try
# Out:
# unique_object_ids                        feature_id  \
# 0                                     min_curvature
# 1                                     std_curvature
# 2                             max_centroid_distance
# 3                            mean_centroid_distance
# 4                  std_mean_centroid_distance_ratio
# ..                                              ...
# 233                                     div_sift_94
# 234                                           UMAP1
# 235                                           UMAP2
# 236                                           UMAP3
# 237                                   cluster_label
#
# unique_object_ids  shape_high_organoid_0_0_0  shape_high_organoid_0_0_1  \
# 0                                   0.828937                   0.816142
# 1                                  -0.964648                  -0.956411
# 2                                  -1.685161                  -1.450278
# 3                                  -1.668918                  -1.495353
# 4                                  -1.192563                  -1.274498
# ..                                       ...                        ...
# 233                                -1.074203                   0.043450
# 234                                10.402882                  11.568656
# 235                                11.776810                  13.010938
# 236                                 8.858575                   5.350818
# 237                                 6.000000                   7.000000
#
# unique_object_ids  shape_high_organoid_0_0_10  shape_high_organoid_0_0_11  \
# 0                                    0.253976                    0.171273
# 1                                   -0.575346                   -0.433419
# 2                                   -0.690502                   -0.558785
# 3                                   -0.698345                   -0.575236
# 4                                    0.344321                    0.492099
# ..                                        ...                         ...
# 233                                 -1.305677                   -1.424020
# 234                                  8.758813                    8.345811
# 235                                 11.071828                   11.135769
# 236                                  6.155564                    6.094432
# 237                                  4.000000                    4.000000
#
# unique_object_ids  shape_high_organoid_0_0_12  shape_high_organoid_0_0_13  \
# 0                                   -0.017806                   -0.188205
# 1                                   -0.256712                   -0.092497
# 2                                   -0.398959                   -0.253842
# 3                                   -0.449315                   -0.308753
# 4                                    0.622940                    0.760787
# ..                                        ...                         ...
# 233                                 -1.127128                   -1.380809
# 234                                  8.369834                    8.363788
# 235                                 11.059614                   10.996665
# 236                                  6.117967                    6.011353
# 237                                  4.000000                    4.000000
#
# unique_object_ids  shape_high_organoid_0_0_14  shape_high_organoid_0_0_15  \
# 0                                   -0.541194                   -1.026630
# 1                                    0.229736                    0.665207
# 2                                   -0.107091                    0.046897
# 3                                   -0.160545                    0.006558
# 4                                    0.880574                    0.999906
# ..                                        ...                         ...
# 233                                 -0.790756                   -1.417473
# 234                                  8.439837                    8.401381
# 235                                 10.946035                   10.988061
# 236                                  6.004143                    6.022503
# 237                                  4.000000                    4.000000
#
# unique_object_ids  shape_high_organoid_0_0_16  ...  \
# 0                                   -1.365016  ...
# 1                                    0.982753  ...
# 2                                    0.199182  ...
# 3                                    0.179792  ...
# 4                                    1.068337  ...
# ..                                        ...  ...
# 233                                 -1.158702  ...
# 234                                  8.339325  ...
# 235                                 10.798628  ...
# 236                                  5.909657  ...
# 237                                  4.000000  ...
#
# unique_object_ids  base_organoid_organoid_9_47_26  \
# 0                                       -1.223769
# 1                                        1.493762
# 2                                        1.456445
# 3                                        1.472984
# 4                                        1.158924
# ..                                            ...
# 233                                     -1.469830
# 234                                      9.610288
# 235                                      8.303946
# 236                                      4.851049
# 237                                      5.000000
#
# unique_object_ids  base_organoid_organoid_9_47_27  \
# 0                                       -1.483170
# 1                                        1.589373
# 2                                        1.553583
# 3                                        1.604474
# 4                                        1.175739
# ..                                            ...
# 233                                     -1.367290
# 234                                      9.701913
# 235                                      8.064074
# 236                                      4.907325
# 237                                      5.000000
#
# unique_object_ids  base_organoid_organoid_9_47_28  \
# 0                                       -1.632359
# 1                                        1.783175
# 2                                        1.691232
# 3                                        1.732826
# 4                                        1.177143
# ..                                            ...
# 233                                     -1.417988
# 234                                      9.659338
# 235                                      8.090141
# 236                                      4.875637
# 237                                      5.000000
#
# unique_object_ids  base_organoid_organoid_9_47_3  \
# 0                                       0.784832
# 1                                      -0.711526
# 2                                      -1.102996
# 3                                      -1.178358
# 4                                      -1.112696
# ..                                           ...
# 233                                    -0.265124
# 234                                    12.339440
# 235                                    12.326022
# 236                                     6.251487
# 237                                     7.000000
#
# unique_object_ids  base_organoid_organoid_9_47_4  \
# 0                                       0.792674
# 1                                      -0.832614
# 2                                      -1.026602
# 3                                      -1.093652
# 4                                      -1.094870
# ..                                           ...
# 233                                     0.180339
# 234                                    10.789778
# 235                                    12.018967
# 236                                     3.213444
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_5  \
# 0                                       0.785215
# 1                                      -0.869808
# 2                                      -0.939846
# 3                                      -1.009232
# 4                                      -1.026702
# ..                                           ...
# 233                                     1.194386
# 234                                     9.144200
# 235                                    11.904536
# 236                                     3.272659
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_6  \
# 0                                       0.753744
# 1                                      -1.141143
# 2                                      -1.064229
# 3                                      -0.916476
# 4                                      -0.937885
# ..                                           ...
# 233                                    -0.708797
# 234                                    12.420177
# 235                                    12.166849
# 236                                     6.314703
# 237                                     7.000000
#
# unique_object_ids  base_organoid_organoid_9_47_7  \
# 0                                       0.786277
# 1                                      -0.783154
# 2                                      -1.034459
# 3                                      -0.839324
# 4                                      -0.848850
# ..                                           ...
# 233                                    -0.428682
# 234                                     9.631266
# 235                                    12.233985
# 236                                     3.355099
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_8  \
# 0                                       0.742837
# 1                                      -0.809698
# 2                                      -0.726230
# 3                                      -0.760821
# 4                                      -0.789856
# ..                                           ...
# 233                                     0.873415
# 234                                     9.900754
# 235                                    11.356116
# 236                                     3.216379
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_9
# 0                                       0.738262
# 1                                      -0.783017
# 2                                      -0.657960
# 3                                      -0.661864
# 4                                      -0.633902
# ..                                           ...
# 233                                     1.471593
# 234                                     9.899714
# 235                                    11.198253
# 236                                     3.157587
# 237                                     3.000000
#
# [238 rows x 9745 columns]

# %%
feature1 = "min_curvature"#"UMAP1"
feature2 = "std_curvature"#"UMAP2"
feature3 = "max_centroid_distance"#"UMAP3"

# creating a scatter plot
scatter_plot_1 = ScatterPlot3D(
    title=f"{feature1} x {feature2} x {feature3}",
    params=[{"linkedDsName":"features","maxItems":1,"type":"RowsAsColsQuery"}, {"linkedDsName":"features","maxItems":1,"type":"RowsAsColsQuery"}, {"linkedDsName":"features","maxItems":1,"type":"RowsAsColsQuery"}],
    #params = [f"Link|{feature1}(Link)|{features_data_try[features_data_try.feature_id == (feature1)].index[0]}", f"Link|{feature2}(Link)|{features_data_try[features_data_try.feature_id == (feature2)].index[0]}", f"Link|{feature3}(Link)|{features_data_try[features_data_try.feature_id == (feature3)].index[0]}"],
    size=[450, 450],
    position=[10, 10],
    default_color="#377eb8",
    brush="poly",
    #on_filter="hide",
    radius=5,
    opacity=0.8,
    center = [10.226573467254639, 11.17284369468689, 5.338449418544769],
    camera={"distance": 50, "theta": 0.5, "phi": 0.5})

# configuring the scatter plot
scatter_plot_1.set_color_by("condition")



# creating a scatter plot
scatter_plot_2 = ScatterPlot3D(
    title=f"{feature1} x {feature2} x {feature3}",
    #params=["angular_second_moment", {"linkedDsName":"features","maxItems":4,"type":"RowsAsColsQuery"}],
    params = [f"Link|{feature1}(Link)|{features_data_try[features_data_try.feature_id == (feature1)].index[0]}", f"Link|{feature2}(Link)|{features_data_try[features_data_try.feature_id == (feature2)].index[0]}", f"Link|{feature3}(Link)|{features_data_try[features_data_try.feature_id == (feature3)].index[0]}"],
    size=[450, 450],
    position=[470, 10],
    default_color="#377eb8",
    brush="poly",
    #on_filter="hide",
    radius=5,
    opacity=0.8,
    center = [10.226573467254639, 11.17284369468689, 5.338449418544769],
    camera={"distance": 50, "theta": 0.5, "phi": 0.5}
)

# configuring the scatter plot
scatter_plot_2.set_color_by("timepoint")




# creating a scatter plot
scatter_plot_3 = ScatterPlot3D(
    title=f"{feature1} x {feature2} x {feature3}",
    #params=["angular_second_moment", {"linkedDsName":"features","maxItems":4,"type":"RowsAsColsQuery"}],
    params = [f"Link|{feature1}(Link)|{features_data_try[features_data_try.feature_id == (feature1)].index[0]}", f"Link|{feature2}(Link)|{features_data_try[features_data_try.feature_id == (feature2)].index[0]}", f"Link|{feature3}(Link)|{features_data_try[features_data_try.feature_id == (feature3)].index[0]}"],
    size=[450, 450],
    position=[930, 10],
    default_color="#377eb8",
    brush="poly",
    #on_filter="hide",
    radius=5,
    opacity=0.8,
    center = [10.226573467254639, 11.17284369468689, 5.338449418544769],
    camera={"distance": 50, "theta": 0.5, "phi": 0.5}
)

# configuring the scatter plot
scatter_plot_3.set_color_by("unique_object_ids")



# creating a table plot
table = TablePlot(
    title="Parameters",
    params=["feature_id"],
    size=[200, 500],
    position=[10, 10]
)

# creating a table plot
selection_dialog = SelectionDialogPlot(
    title="Filtering",
    params=["condition", "timepoint", "unique_object_ids"],
    size=[200, 400],
    position=[10, 500]
)

# creating a table plot
stacked_row_chart = StackedRowChart(
    title="Abundance of objects per timepoint",
    params=["timepoint_cat", "cluster_label"],
     size=[700, 600],
     position=[10, 470]
)

# %%
organoids_data
# Out:
#                      unique_object_ids        condition  timepoint  \
# 0            shape_high_organoid_0_0_0       shape_high          0
# 1       base_organoid_organoid_22_15_0    base_organoid          0
# 2           shape_low_organoid_30_24_0        shape_low          0
# 3            shape_low_organoid_2_12_0        shape_low          0
# 4      appearance_low_organoid_44_39_0   appearance_low          0
# ...                                ...              ...        ...
# 9739  appearance_high_organoid_14_6_28  appearance_high         28
# 9740       shape_low_organoid_42_37_28        shape_low         28
# 9741       shape_low_organoid_43_38_28        shape_low         28
# 9742       shape_low_organoid_37_31_28        shape_low         28
# 9743  appearance_high_organoid_16_8_28  appearance_high         28
#
#      timepoint_cat
# 0     timepoint_00
# 1     timepoint_00
# 2     timepoint_00
# 3     timepoint_00
# 4     timepoint_00
# ...            ...
# 9739  timepoint_28
# 9740  timepoint_28
# 9741  timepoint_28
# 9742  timepoint_28
# 9743  timepoint_28
#
# [9744 rows x 4 columns]

# %%
features_data_try
# Out:
# unique_object_ids                        feature_id  \
# 0                                     min_curvature
# 1                                     std_curvature
# 2                             max_centroid_distance
# 3                            mean_centroid_distance
# 4                  std_mean_centroid_distance_ratio
# ..                                              ...
# 233                                     div_sift_94
# 234                                           UMAP1
# 235                                           UMAP2
# 236                                           UMAP3
# 237                                   cluster_label
#
# unique_object_ids  shape_high_organoid_0_0_0  shape_high_organoid_0_0_1  \
# 0                                   0.828937                   0.816142
# 1                                  -0.964648                  -0.956411
# 2                                  -1.685161                  -1.450278
# 3                                  -1.668918                  -1.495353
# 4                                  -1.192563                  -1.274498
# ..                                       ...                        ...
# 233                                -1.074203                   0.043450
# 234                                10.402882                  11.568656
# 235                                11.776810                  13.010938
# 236                                 8.858575                   5.350818
# 237                                 6.000000                   7.000000
#
# unique_object_ids  shape_high_organoid_0_0_10  shape_high_organoid_0_0_11  \
# 0                                    0.253976                    0.171273
# 1                                   -0.575346                   -0.433419
# 2                                   -0.690502                   -0.558785
# 3                                   -0.698345                   -0.575236
# 4                                    0.344321                    0.492099
# ..                                        ...                         ...
# 233                                 -1.305677                   -1.424020
# 234                                  8.758813                    8.345811
# 235                                 11.071828                   11.135769
# 236                                  6.155564                    6.094432
# 237                                  4.000000                    4.000000
#
# unique_object_ids  shape_high_organoid_0_0_12  shape_high_organoid_0_0_13  \
# 0                                   -0.017806                   -0.188205
# 1                                   -0.256712                   -0.092497
# 2                                   -0.398959                   -0.253842
# 3                                   -0.449315                   -0.308753
# 4                                    0.622940                    0.760787
# ..                                        ...                         ...
# 233                                 -1.127128                   -1.380809
# 234                                  8.369834                    8.363788
# 235                                 11.059614                   10.996665
# 236                                  6.117967                    6.011353
# 237                                  4.000000                    4.000000
#
# unique_object_ids  shape_high_organoid_0_0_14  shape_high_organoid_0_0_15  \
# 0                                   -0.541194                   -1.026630
# 1                                    0.229736                    0.665207
# 2                                   -0.107091                    0.046897
# 3                                   -0.160545                    0.006558
# 4                                    0.880574                    0.999906
# ..                                        ...                         ...
# 233                                 -0.790756                   -1.417473
# 234                                  8.439837                    8.401381
# 235                                 10.946035                   10.988061
# 236                                  6.004143                    6.022503
# 237                                  4.000000                    4.000000
#
# unique_object_ids  shape_high_organoid_0_0_16  ...  \
# 0                                   -1.365016  ...
# 1                                    0.982753  ...
# 2                                    0.199182  ...
# 3                                    0.179792  ...
# 4                                    1.068337  ...
# ..                                        ...  ...
# 233                                 -1.158702  ...
# 234                                  8.339325  ...
# 235                                 10.798628  ...
# 236                                  5.909657  ...
# 237                                  4.000000  ...
#
# unique_object_ids  base_organoid_organoid_9_47_26  \
# 0                                       -1.223769
# 1                                        1.493762
# 2                                        1.456445
# 3                                        1.472984
# 4                                        1.158924
# ..                                            ...
# 233                                     -1.469830
# 234                                      9.610288
# 235                                      8.303946
# 236                                      4.851049
# 237                                      5.000000
#
# unique_object_ids  base_organoid_organoid_9_47_27  \
# 0                                       -1.483170
# 1                                        1.589373
# 2                                        1.553583
# 3                                        1.604474
# 4                                        1.175739
# ..                                            ...
# 233                                     -1.367290
# 234                                      9.701913
# 235                                      8.064074
# 236                                      4.907325
# 237                                      5.000000
#
# unique_object_ids  base_organoid_organoid_9_47_28  \
# 0                                       -1.632359
# 1                                        1.783175
# 2                                        1.691232
# 3                                        1.732826
# 4                                        1.177143
# ..                                            ...
# 233                                     -1.417988
# 234                                      9.659338
# 235                                      8.090141
# 236                                      4.875637
# 237                                      5.000000
#
# unique_object_ids  base_organoid_organoid_9_47_3  \
# 0                                       0.784832
# 1                                      -0.711526
# 2                                      -1.102996
# 3                                      -1.178358
# 4                                      -1.112696
# ..                                           ...
# 233                                    -0.265124
# 234                                    12.339440
# 235                                    12.326022
# 236                                     6.251487
# 237                                     7.000000
#
# unique_object_ids  base_organoid_organoid_9_47_4  \
# 0                                       0.792674
# 1                                      -0.832614
# 2                                      -1.026602
# 3                                      -1.093652
# 4                                      -1.094870
# ..                                           ...
# 233                                     0.180339
# 234                                    10.789778
# 235                                    12.018967
# 236                                     3.213444
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_5  \
# 0                                       0.785215
# 1                                      -0.869808
# 2                                      -0.939846
# 3                                      -1.009232
# 4                                      -1.026702
# ..                                           ...
# 233                                     1.194386
# 234                                     9.144200
# 235                                    11.904536
# 236                                     3.272659
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_6  \
# 0                                       0.753744
# 1                                      -1.141143
# 2                                      -1.064229
# 3                                      -0.916476
# 4                                      -0.937885
# ..                                           ...
# 233                                    -0.708797
# 234                                    12.420177
# 235                                    12.166849
# 236                                     6.314703
# 237                                     7.000000
#
# unique_object_ids  base_organoid_organoid_9_47_7  \
# 0                                       0.786277
# 1                                      -0.783154
# 2                                      -1.034459
# 3                                      -0.839324
# 4                                      -0.848850
# ..                                           ...
# 233                                    -0.428682
# 234                                     9.631266
# 235                                    12.233985
# 236                                     3.355099
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_8  \
# 0                                       0.742837
# 1                                      -0.809698
# 2                                      -0.726230
# 3                                      -0.760821
# 4                                      -0.789856
# ..                                           ...
# 233                                     0.873415
# 234                                     9.900754
# 235                                    11.356116
# 236                                     3.216379
# 237                                     3.000000
#
# unique_object_ids  base_organoid_organoid_9_47_9
# 0                                       0.738262
# 1                                      -0.783017
# 2                                      -0.657960
# 3                                      -0.661864
# 4                                      -0.633902
# ..                                           ...
# 233                                     1.471593
# 234                                     9.899714
# 235                                    11.198253
# 236                                     3.157587
# 237                                     3.000000
#
# [238 rows x 9745 columns]

# %%
organoids_data
# Out:
#                      unique_object_ids        condition  timepoint  \
# 0            shape_high_organoid_0_0_0       shape_high          0
# 1       base_organoid_organoid_22_15_0    base_organoid          0
# 2           shape_low_organoid_30_24_0        shape_low          0
# 3            shape_low_organoid_2_12_0        shape_low          0
# 4      appearance_low_organoid_44_39_0   appearance_low          0
# ...                                ...              ...        ...
# 9739  appearance_high_organoid_14_6_28  appearance_high         28
# 9740       shape_low_organoid_42_37_28        shape_low         28
# 9741       shape_low_organoid_43_38_28        shape_low         28
# 9742       shape_low_organoid_37_31_28        shape_low         28
# 9743  appearance_high_organoid_16_8_28  appearance_high         28
#
#      timepoint_cat
# 0     timepoint_00
# 1     timepoint_00
# 2     timepoint_00
# 3     timepoint_00
# 4     timepoint_00
# ...            ...
# 9739  timepoint_28
# 9740  timepoint_28
# 9741  timepoint_28
# 9742  timepoint_28
# 9743  timepoint_28
#
# [9744 rows x 4 columns]

# %%
# setting up and serving the MDV project
base = os.path.expanduser('~/mdv')
project_path = os.path.join(base, 'spot1') # defining the location where the project metadata will be stored
p = MDVProject(os.path.expanduser(project_path), delete_existing=True)

# # adding the two data sources to the project
p.add_datasource("data_organoids", organoids_data)
p.add_datasource("features", features_data_try.iloc[:,:1])
#p.add_datasource("features_trajectories", features_trajectories_try.iloc[:,:1])
# Out:
# starting add_datasource
# is ds None? None
# got passed the ds check
# created h5 group without error
# - adding column 'unique_object_ids' to datasource 'data_organoids'
# - adding column 'condition' to datasource 'data_organoids'
# - adding column 'timepoint' to datasource 'data_organoids'
# - adding column 'timepoint_cat' to datasource 'data_organoids'
#  - non-dodgy columns: [{'datatype': 'text16', 'name': 'unique_object_ids', 'field': 'unique_object_ids', 'values': ['shape_high_organoid_0_0_0', 'movement_low_organoid_5_43_19', 'shape_low_organoid_13_5_19', 'shape_high_organoid_33_27_19', 'appearance_high_organoid_0_0_19', 'movement_high_organoid_11_3_19', 'shape_high_organoid_39_33_19', 'shape_high_organoid_12_4_19', 'base_organoid_organoid_9_47_19', 'shape_low_organoid_8_46_19', 'appearance_low_organoid_6_44_19', 'shape_high_organoid_47_42_19', 'shape_high_organoid_32_26_19', 'movement_high_organoid_23_16_19', 'movement_high_organoid_0_0_19', 'shape_high_organoid_31_25_19', 'appearance_high_organoid_47_42_19', 'movement_low_organoid_35_29_19', 'appearance_low_organoid_29_22_19', 'shape_high_organoid_16_8_19', 'movement_high_organoid_22_15_19', 'movement_low_organoid_38_32_19', 'shape_low_organoid_14_6_19', 'appearance_high_organoid_46_41_19', 'movement_high_organoid_13_5_19', 'movement_high_organoid_8_46_19', 'appearance_high_organoid_13_5_19', 'movement_low_organoid_37_31_19', 'shape_high_organoid_15_7_19', 'movement_high_organoid_21_14_19', 'appearance_high_organoid_12_4_19', 'shape_low_organoid_30_24_19', 'appearance_high_organoid_8_46_19', 'movement_high_organoid_12_4_19', 'shape_high_organoid_11_3_19', 'movement_low_organoid_4_34_19', 'shape_low_organoid_46_41_19', 'appearance_low_organoid_8_46_19', 'movement_low_organoid_9_47_19', 'shape_high_organoid_17_9_19', 'appearance_low_organoid_21_14_19', 'movement_low_organoid_36_30_19', 'appearance_low_organoid_22_15_19', 'shape_low_organoid_12_4_19', 'movement_high_organoid_24_17_19', 'appearance_low_organoid_9_47_19', 'base_organoid_organoid_31_25_19', 'movement_high_organoid_39_33_19', 'shape_low_organoid_44_39_19', 'appearance_low_organoid_0_0_19', 'shape_high_organoid_3_23_19', 'movement_low_organoid_8_46_19', 'appearance_high_organoid_2_12_19', 'shape_low_organoid_47_42_19', 'appearance_low_organoid_20_13_19', 'shape_low_organoid_15_7_19', 'movement_low_organoid_7_45_19', 'base_organoid_organoid_30_24_19', 'appearance_low_organoid_25_18_19', 'movement_high_organoid_6_44_19', 'shape_high_organoid_34_28_19', 'appearance_high_organoid_45_40_19', 'movement_low_organoid_39_33_19', 'movement_high_organoid_25_18_19', 'appearance_low_organoid_7_45_19', 'shape_low_organoid_43_38_19', 'appearance_low_organoid_10_2_19', 'appearance_low_organoid_23_16_19', 'appearance_high_organoid_28_21_19', 'movement_low_organoid_18_10_19', 'appearance_high_organoid_37_31_19', 'shape_low_organoid_16_8_19', 'shape_high_organoid_14_6_19', 'base_organoid_organoid_0_0_19', 'movement_low_organoid_0_0_19', 'appearance_high_organoid_21_14_19', 'appearance_high_organoid_29_22_19', 'movement_low_organoid_47_42_19', 'appearance_high_organoid_44_39_19', 'shape_low_organoid_28_21_19', 'appearance_low_organoid_12_4_19', 'shape_high_organoid_41_36_19', 'base_organoid_organoid_13_5_19', 'shape_high_organoid_35_29_19', 'movement_high_organoid_28_21_19', 'shape_low_organoid_40_35_19', 'appearance_low_organoid_47_42_19', 'movement_high_organoid_20_13_19', 'shape_low_organoid_19_11_19', 'shape_low_organoid_4_34_19', 'shape_high_organoid_8_46_19', 'shape_high_organoid_29_22_19', 'appearance_low_organoid_46_41_19', 'appearance_low_organoid_1_1_19', 'appearance_high_organoid_1_1_19', 'movement_high_organoid_4_34_19', 'base_organoid_organoid_38_32_19', 'shape_high_organoid_38_32_19', 'movement_high_organoid_5_43_19', 'base_organoid_organoid_10_2_19', 'base_organoid_organoid_2_12_19', 'appearance_high_organoid_38_32_19', 'shape_low_organoid_31_25_19', 'base_organoid_organoid_41_36_19', 'movement_high_organoid_41_36_19', 'shape_low_organoid_42_37_19', 'shape_high_organoid_10_2_19', 'appearance_high_organoid_7_45_19', 'appearance_low_organoid_30_24_19', 'shape_high_organoid_30_24_19', 'base_organoid_organoid_44_39_19', 'movement_low_organoid_10_2_19', 'movement_high_organoid_26_19_19', 'base_organoid_organoid_14_6_19', 'movement_low_organoid_31_25_19', 'appearance_high_o ...
# --- setting datasource metadata: {'name': 'data_organoids', 'columns': [{'datatype': 'text16', 'name': 'unique_object_ids', 'field': 'unique_object_ids', 'values': ['shape_high_organoid_0_0_0', 'movement_low_organoid_5_43_19', 'shape_low_organoid_13_5_19', 'shape_high_organoid_33_27_19', 'appearance_high_organoid_0_0_19', 'movement_high_organoid_11_3_19', 'shape_high_organoid_39_33_19', 'shape_high_organoid_12_4_19', 'base_organoid_organoid_9_47_19', 'shape_low_organoid_8_46_19', 'appearance_low_organoid_6_44_19', 'shape_high_organoid_47_42_19', 'shape_high_organoid_32_26_19', 'movement_high_organoid_23_16_19', 'movement_high_organoid_0_0_19', 'shape_high_organoid_31_25_19', 'appearance_high_organoid_47_42_19', 'movement_low_organoid_35_29_19', 'appearance_low_organoid_29_22_19', 'shape_high_organoid_16_8_19', 'movement_high_organoid_22_15_19', 'movement_low_organoid_38_32_19', 'shape_low_organoid_14_6_19', 'appearance_high_organoid_46_41_19', 'movement_high_organoid_13_5_19', 'movement_high_organoid_8_46_19', 'appearance_high_organoid_13_5_19', 'movement_low_organoid_37_31_19', 'shape_high_organoid_15_7_19', 'movement_high_organoid_21_14_19', 'appearance_high_organoid_12_4_19', 'shape_low_organoid_30_24_19', 'appearance_high_organoid_8_46_19', 'movement_high_organoid_12_4_19', 'shape_high_organoid_11_3_19', 'movement_low_organoid_4_34_19', 'shape_low_organoid_46_41_19', 'appearance_low_organoid_8_46_19', 'movement_low_organoid_9_47_19', 'shape_high_organoid_17_9_19', 'appearance_low_organoid_21_14_19', 'movement_low_organoid_36_30_19', 'appearance_low_organoid_22_15_19', 'shape_low_organoid_12_4_19', 'movement_high_organoid_24_17_19', 'appearance_low_organoid_9_47_19', 'base_organoid_organoid_31_25_19', 'movement_high_organoid_39_33_19', 'shape_low_organoid_44_39_19', 'appearance_low_organoid_0_0_19', 'shape_high_organoid_3_23_19', 'movement_low_organoid_8_46_19', 'appearance_high_organoid_2_12_19', 'shape_low_organoid_47_42_19', 'appearance_low_organoid_20_13_19', 'shape_low_organoid_15_7_19', 'movement_low_organoid_7_45_19', 'base_organoid_organoid_30_24_19', 'appearance_low_organoid_25_18_19', 'movement_high_organoid_6_44_19', 'shape_high_organoid_34_28_19', 'appearance_high_organoid_45_40_19', 'movement_low_organoid_39_33_19', 'movement_high_organoid_25_18_19', 'appearance_low_organoid_7_45_19', 'shape_low_organoid_43_38_19', 'appearance_low_organoid_10_2_19', 'appearance_low_organoid_23_16_19', 'appearance_high_organoid_28_21_19', 'movement_low_organoid_18_10_19', 'appearance_high_organoid_37_31_19', 'shape_low_organoid_16_8_19', 'shape_high_organoid_14_6_19', 'base_organoid_organoid_0_0_19', 'movement_low_organoid_0_0_19', 'appearance_high_organoid_21_14_19', 'appearance_high_organoid_29_22_19', 'movement_low_organoid_47_42_19', 'appearance_high_organoid_44_39_19', 'shape_low_organoid_28_21_19', 'appearance_low_organoid_12_4_19', 'shape_high_organoid_41_36_19', 'base_organoid_organoid_13_5_19', 'shape_high_organoid_35_29_19', 'movement_high_organoid_28_21_19', 'shape_low_organoid_40_35_19', 'appearance_low_organoid_47_42_19', 'movement_high_organoid_20_13_19', 'shape_low_organoid_19_11_19', 'shape_low_organoid_4_34_19', 'shape_high_organoid_8_46_19', 'shape_high_organoid_29_22_19', 'appearance_low_organoid_46_41_19', 'appearance_low_organoid_1_1_19', 'appearance_high_organoid_1_1_19', 'movement_high_organoid_4_34_19', 'base_organoid_organoid_38_32_19', 'shape_high_organoid_38_32_19', 'movement_high_organoid_5_43_19', 'base_organoid_organoid_10_2_19', 'base_organoid_organoid_2_12_19', 'appearance_high_organoid_38_32_19', 'shape_low_organoid_31_25_19', 'base_organoid_organoid_41_36_19', 'movement_high_organoid_41_36_19', 'shape_low_organoid_42_37_19', 'shape_high_organoid_10_2_19', 'appearance_high_organoid_7_45_19', 'appearance_low_organoid_30_24_19', 'shape_high_organoid_30_24_19', 'base_organoid_organoid_44_39_19', 'movement_low_organoid_10_2_19', 'movement_high_organoid_26_19_19', 'base_organoid_organoid_14_6_19', 'mo ...
# Updated datasource metadata
# In set_view
# default
# In MDVProject.add_datasource: Added datasource successfully 'data_organoids'
# starting add_datasource
# is ds None? None
# got passed the ds check
# data_organoids
# created h5 group without error
# - adding column 'feature_id' to datasource 'features'
#  - non-dodgy columns: [{'datatype': 'text', 'name': 'feature_id', 'field': 'feature_id', 'values': ['min_curvature', 'sift_motion_6', 'stddev_divergence_global_flow', 'hist_bin_4_region_001', 'stddev_speed_flow_region1', 'hist_bin_4_region_002', 'hist_bin_5_region_002', 'mean_speed_flow_region_2', 'stddev_speed_flow_region2', 'hist_bin_2_region_003', 'hist_bin_3_region_003', 'mean_speed_flow_region_3', 'stddev_speed_flow_region3', 'sift_motion_4', 'sift_motion_11', 'mean_speed_global_flow', 'sift_motion_16', 'sift_motion_18', 'sift_motion_22', 'sift_motion_31', 'sift_motion_33', 'sift_motion_42', 'sift_motion_43', 'sift_motion_48', 'sift_motion_54', 'sift_motion_55', 'sift_motion_68', 'sift_motion_69', 'stddev_curl_global_flow', 'mean_speed_global', 'sift_motion_86', 'sift_appear_96', 'sift_appear_71', 'sift_appear_73', 'sift_appear_74', 'sift_appear_79', 'sift_appear_80', 'sift_appear_82', 'sift_appear_83', 'sift_appear_86', 'sift_appear_87', 'sift_appear_89', 'sift_appear_91', 'sift_appear_95', 'sift_appear_97', 'sift_appear_128', 'sift_appear_99', 'sift_appear_101', 'sift_appear_106', 'sift_appear_107', 'sift_appear_108', 'sift_appear_111', 'sift_appear_114', 'sift_appear_116', 'sift_appear_121', 'sift_appear_122', 'sift_appear_123', 'sift_appear_124', 'sift_motion_82', 'sift_motion_89', 'std_curvature', 'div_sift_52', 'curl_sift_117', 'curl_sift_120', 'div_sift_4', 'div_sift_8', 'div_sift_11', 'div_sift_14', 'div_sift_16', 'div_sift_17', 'div_sift_20', 'div_sift_37', 'div_sift_45', 'div_sift_49', 'div_sift_56', 'curl_sift_115', 'div_sift_69', 'div_sift_71', 'div_sift_77', 'div_sift_79', 'div_sift_81', 'div_sift_84', 'div_sift_89', 'div_sift_93', 'div_sift_94', 'UMAP1', 'UMAP2', 'UMAP3', 'curl_sift_116', 'curl_sift_113', 'sift_motion_102', 'curl_sift_51', 'sift_motion_110', 'sift_motion_119', 'sift_motion_120', 'sift_motion_122', 'sift_motion_124', 'curl_sift_4', 'curl_sift_8', 'curl_sift_11', 'curl_sift_16', 'curl_sift_29', 'curl_sift_41', 'curl_sift_48', 'curl_sift_52', 'curl_sift_112', 'curl_sift_53', 'curl_sift_57', 'curl_sift_62', 'curl_sift_64', 'curl_sift_68', 'curl_sift_69', 'curl_sift_70', 'curl_sift_78', 'curl_sift_84', 'curl_sift_86', 'curl_sift_101', 'curl_sift_109', 'sift_appear_70', 'sift_appear_69', 'sift_appear_66', 'Fourier_35', 'zernike_moments_10', 'zernike_moments_11', 'zernike_moments_12', 'zernike_moments_13', 'zernike_moments_22', 'Fourier_1', 'Fourier_2', 'Fourier_3', 'Fourier_4', 'Fourier_6', 'Fourier_8', 'Fourier_15', 'Shape_Context_57', 'zernike_moments_7', 'Shape_Context_76', 'Shape_Context_86', 'Shape_Context_91', 'Shape_Context_98', 'Shape_Context_104', 'Shape_Context_113', 'Shape_Context_114', 'Shape_Context_118', 'Shape_Context_152', 'Shape_Context_157', 'Shape_Context_158', 'Shape_Context_178', 'zernike_moments_8', 'zernike_moments_6', 'sift_appear_65', 'perimeter', 'max_centroid_distance', 'mean_centroid_distance', 'std_mean_centroid_distance_ratio', 'max_chordal_distance', 'max_min_centroid_distance_ratio', 'chordal_hist_bin_2', 'chordal_hist_bin_3', 'chordal_hist_bin_4', 'chordal_hist_bin_5', 'chordal_hist_bin_6', 'chordal_hist_bin_7', 'chordal_hist_bin_8', 'equivalent_diameter', 'zernike_moments_5', 'major_axis_length', 'minor_axis_length', 'area_perim_aspect_ratio', 'major_minor_axis_ratio', 'moment_eccentricity', 'hu_moments_1', 'hu_moments_2', 'hu_moments_3', 'hu_moments_4', 'zernike_moments_2', 'zernike_moments_3', 'zernike_moments_4', 'Shape_Context_212', 'Shape_Context_213', 'Shape_Context_217', 'sift_appear_34', 'sift_appear_13', 'sift_appear_15', 'sift_appear_16', 'sift_appear_18', 'sift_appear_20', 'sift_appear_21', 'sift_appear_24', 'sift_appear_26', 'sift_appear_27', 'sift_appear_28', 'sift_appear_31', 'sift_appear_32', 'sift_appear_35', 'Shape_Context_221', 'sift_appear_38', 'sift_appear_39', 'sift_appear_40', 'sift_appear_44', 'sift_appear_47', 'sift_appear_48', 'sift_appear_52', 'sift_appear_54', 'sift_appear_55', 'sift_appear_58', 'sift_appear_59', 'sift_appear_63', 'sift_ ...
# --- setting datasource metadata: {'name': 'features', 'columns': [{'datatype': 'text', 'name': 'feature_id', 'field': 'feature_id', 'values': ['min_curvature', 'sift_motion_6', 'stddev_divergence_global_flow', 'hist_bin_4_region_001', 'stddev_speed_flow_region1', 'hist_bin_4_region_002', 'hist_bin_5_region_002', 'mean_speed_flow_region_2', 'stddev_speed_flow_region2', 'hist_bin_2_region_003', 'hist_bin_3_region_003', 'mean_speed_flow_region_3', 'stddev_speed_flow_region3', 'sift_motion_4', 'sift_motion_11', 'mean_speed_global_flow', 'sift_motion_16', 'sift_motion_18', 'sift_motion_22', 'sift_motion_31', 'sift_motion_33', 'sift_motion_42', 'sift_motion_43', 'sift_motion_48', 'sift_motion_54', 'sift_motion_55', 'sift_motion_68', 'sift_motion_69', 'stddev_curl_global_flow', 'mean_speed_global', 'sift_motion_86', 'sift_appear_96', 'sift_appear_71', 'sift_appear_73', 'sift_appear_74', 'sift_appear_79', 'sift_appear_80', 'sift_appear_82', 'sift_appear_83', 'sift_appear_86', 'sift_appear_87', 'sift_appear_89', 'sift_appear_91', 'sift_appear_95', 'sift_appear_97', 'sift_appear_128', 'sift_appear_99', 'sift_appear_101', 'sift_appear_106', 'sift_appear_107', 'sift_appear_108', 'sift_appear_111', 'sift_appear_114', 'sift_appear_116', 'sift_appear_121', 'sift_appear_122', 'sift_appear_123', 'sift_appear_124', 'sift_motion_82', 'sift_motion_89', 'std_curvature', 'div_sift_52', 'curl_sift_117', 'curl_sift_120', 'div_sift_4', 'div_sift_8', 'div_sift_11', 'div_sift_14', 'div_sift_16', 'div_sift_17', 'div_sift_20', 'div_sift_37', 'div_sift_45', 'div_sift_49', 'div_sift_56', 'curl_sift_115', 'div_sift_69', 'div_sift_71', 'div_sift_77', 'div_sift_79', 'div_sift_81', 'div_sift_84', 'div_sift_89', 'div_sift_93', 'div_sift_94', 'UMAP1', 'UMAP2', 'UMAP3', 'curl_sift_116', 'curl_sift_113', 'sift_motion_102', 'curl_sift_51', 'sift_motion_110', 'sift_motion_119', 'sift_motion_120', 'sift_motion_122', 'sift_motion_124', 'curl_sift_4', 'curl_sift_8', 'curl_sift_11', 'curl_sift_16', 'curl_sift_29', 'curl_sift_41', 'curl_sift_48', 'curl_sift_52', 'curl_sift_112', 'curl_sift_53', 'curl_sift_57', 'curl_sift_62', 'curl_sift_64', 'curl_sift_68', 'curl_sift_69', 'curl_sift_70', 'curl_sift_78', 'curl_sift_84', 'curl_sift_86', 'curl_sift_101', 'curl_sift_109', 'sift_appear_70', 'sift_appear_69', 'sift_appear_66', 'Fourier_35', 'zernike_moments_10', 'zernike_moments_11', 'zernike_moments_12', 'zernike_moments_13', 'zernike_moments_22', 'Fourier_1', 'Fourier_2', 'Fourier_3', 'Fourier_4', 'Fourier_6', 'Fourier_8', 'Fourier_15', 'Shape_Context_57', 'zernike_moments_7', 'Shape_Context_76', 'Shape_Context_86', 'Shape_Context_91', 'Shape_Context_98', 'Shape_Context_104', 'Shape_Context_113', 'Shape_Context_114', 'Shape_Context_118', 'Shape_Context_152', 'Shape_Context_157', 'Shape_Context_158', 'Shape_Context_178', 'zernike_moments_8', 'zernike_moments_6', 'sift_appear_65', 'perimeter', 'max_centroid_distance', 'mean_centroid_distance', 'std_mean_centroid_distance_ratio', 'max_chordal_distance', 'max_min_centroid_distance_ratio', 'chordal_hist_bin_2', 'chordal_hist_bin_3', 'chordal_hist_bin_4', 'chordal_hist_bin_5', 'chordal_hist_bin_6', 'chordal_hist_bin_7', 'chordal_hist_bin_8', 'equivalent_diameter', 'zernike_moments_5', 'major_axis_length', 'minor_axis_length', 'area_perim_aspect_ratio', 'major_minor_axis_ratio', 'moment_eccentricity', 'hu_moments_1', 'hu_moments_2', 'hu_moments_3', 'hu_moments_4', 'zernike_moments_2', 'zernike_moments_3', 'zernike_moments_4', 'Shape_Context_212', 'Shape_Context_213', 'Shape_Context_217', 'sift_appear_34', 'sift_appear_13', 'sift_appear_15', 'sift_appear_16', 'sift_appear_18', 'sift_appear_20', 'sift_appear_21', 'sift_appear_24', 'sift_appear_26', 'sift_appear_27', 'sift_appear_28', 'sift_appear_31', 'sift_appear_32', 'sift_appear_35', 'Shape_Context_221', 'sift_appear_38', 'sift_appear_39', 'sift_appear_40', 'sift_appear_44', 'sift_appear_47', 'sift_appear_48', 'sift_appear_52', 'sift_appear_54', 'sift_appear_55', 'sift_appear_58', ...
# Updated datasource metadata
# In set_view
# default
# In MDVProject.add_datasource: Added datasource successfully 'features'
# []

# %%
numeric_data = features_data_try.T.iloc[1:, :].apply(pd.to_numeric, errors='coerce').values
numeric_data_trajectories = features_trajectories.T.iloc[1:, :].apply(pd.to_numeric, errors='coerce').values

#p.add_rows_as_columns_link("data_organoids","features_trajectories","feature_id","Link_trajectories")
#p.add_rows_as_columns_subgroup("data_organoids","features_trajectories","Link_trajectories",numeric_data_trajectories.T) #add the gene expression 

# # creating the link between the two datasets so that selecting a subset of genes to add the expression in cells is enabled
p.add_rows_as_columns_link("data_organoids","features","feature_id","Link")
p.add_rows_as_columns_subgroup("data_organoids","features","Link",numeric_data.T) #add the gene expression

# %%
# # converting the chart implementation outputs to JSON and setting up the project view
list_charts_cells = []
list_charts_features = []
list_charts_features_trajectories = []


# cells panel
#list_charts_cells.extend([scatter_plot_1.plot_data, scatter_plot_2.plot_data, scatter_plot_3.plot_data, selection_dialog.plot_data, stacked_row_chart.plot_data]) #dot_plot.plot_data,
list_charts_cells.extend([scatter_plot_1.plot_data, selection_dialog.plot_data, stacked_row_chart.plot_data]) #dot_plot.plot_data,

list_charts_features.extend([table.plot_data])

# setting the config combining the two panels
view_config = {'initialCharts': {"data_organoids": list_charts_cells, "features": list_charts_features}}#, "features_trajectories": list_charts_features_trajectories}}

# adding the view to the project configuration
p.set_view("default", view_config)

p.set_editable(True)
# Out:
# In set_view
# default

# %%
# serving the project
p.serve()
# Out:
# # setting keys and variables
# # Crawl the local repository to get a list of relevant file paths
# Block 'b1: Local repo crawling' took 0.0237 seconds
# # Initialize a text splitter for chunking the code strings
# # Split the code documents into chunks using the text splitter
# Block 'b2: Text splitter initialising' took 0.0004 seconds
# # Initialize an instance of the OpenAIEmbeddings class
# created Flask <Flask 'mdvtools.server'>
# [[[ socket.io ]]] [2025-05-12 22:04:52] - socketio initialized
# websocket/chat enabled for
#  * Serving Flask app 'mdvtools.server'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5050
#  * Running on http://192.168.10.100:5050
# Press CTRL+C to quit
# 127.0.0.1 - - [12/May/2025 22:04:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:52] "GET /static/assets/mdv.css HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:52] "GET /static/js/mdv.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/Button-BD828UfA.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/Image-Df4aT-_p.js HTTP/1.1" 304 -
# recieved request to project_index
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/datasourceWorker-BDVgcx14.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /projects HTTP/1.1" 404 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /datasources.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /views.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /socket.io/?EIO=4&transport=polling&t=kn3i35px HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "POST /get_view HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/filteredIndexWorker-CEl1713S.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/filteredIndexWorker-CEl1713S.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /socket.io/?EIO=4&transport=polling&t=kn3iupvx&sid=vekuNO8jBnbRwfFNAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "POST /socket.io/?EIO=4&transport=polling&t=kn3iu4wu&sid=vekuNO8jBnbRwfFNAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /socket.io/?EIO=4&transport=polling&t=kn3j4cqv&sid=vekuNO8jBnbRwfFNAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-solid-900.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "POST /get_data HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/catWorker-D5lhlpxE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/catWorker-D5lhlpxE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/rawHistogramWorker-CYPeI1fE.js HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/assets/binWorker-DIC2QqPk.js HTTP/1.1" 304 -
# [[[ socket.io ]]] [2025-05-12 22:04:53] - WebSocket client connected, args: ImmutableMultiDict([('EIO', '4'), ('transport', 'polling'), ('t', 'kn3i35px')])
# [[[ socket.io ]]] [2025-05-12 22:04:53] - ping: {'type': 'ping'}
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-brands-400.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-regular-400.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-300-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-300-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-solid-900.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-300-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-300-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-300-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-300-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-400-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-500-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-700-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-700-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-700-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-700-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-700-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-700-normal.woff2 HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-brands-400.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-regular-400.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-300-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-300-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-solid-900.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-300-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-400-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-400-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-300-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-300-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-400-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-300-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-400-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-400-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-400-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-500-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-500-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-500-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-500-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-500-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-500-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-ext-700-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-cyrillic-700-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-greek-700-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-ext-700-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-vietnamese-700-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/roboto-latin-700-normal.woff HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-brands-400.ttf HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-regular-400.ttf HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:53] "GET /static/img/fa-solid-900.ttf HTTP/1.1" 304 -
# 127.0.0.1 - - [12/May/2025 22:04:54] "GET /state.json HTTP/1.1" 200 -
# Access level required: editable
# In set_view
# default
# 127.0.0.1 - - [12/May/2025 22:04:54] "POST /save_state HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:54] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:54] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:55] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:55] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:55] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:56] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:56] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:56] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:57] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:57] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:57] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7pvdbe HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7pvmcf HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7pw5vt HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "POST /socket.io/?EIO=4&transport=polling&t=kn7qg803&sid=TMvyEdRxCB2UBNdNAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7qhbl8&sid=TMvyEdRxCB2UBNdNAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "POST /socket.io/?EIO=4&transport=polling&t=kn7qlii4&sid=gwEG8CX0oXIIK-KqAAAD HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7qmzdw&sid=gwEG8CX0oXIIK-KqAAAD HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "POST /socket.io/?EIO=4&transport=polling&t=kn7qqcdj&sid=3j1sLl7LDeqOZnEzAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7qr19b&sid=3j1sLl7LDeqOZnEzAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7qx1d1&sid=TMvyEdRxCB2UBNdNAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "POST /socket.io/?EIO=4&transport=polling&t=kn7qxfep&sid=TMvyEdRxCB2UBNdNAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7r33yi&sid=gwEG8CX0oXIIK-KqAAAD HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "POST /socket.io/?EIO=4&transport=polling&t=kn7r3y4g&sid=gwEG8CX0oXIIK-KqAAAD HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "POST /socket.io/?EIO=4&transport=polling&t=kn7r3ynj&sid=3j1sLl7LDeqOZnEzAAAE HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:58] "GET /socket.io/?EIO=4&transport=polling&t=kn7r3j1q&sid=3j1sLl7LDeqOZnEzAAAE HTTP/1.1" 200 -
# [[[ socket.io ]]] [2025-05-12 22:04:58] - WebSocket client connected, args: ImmutableMultiDict([('EIO', '4'), ('transport', 'polling'), ('t', 'kn7pvdbe')])
# [[[ socket.io ]]] [2025-05-12 22:04:58] - WebSocket client connected, args: ImmutableMultiDict([('EIO', '4'), ('transport', 'polling'), ('t', 'kn7pvmcf')])
# [[[ socket.io ]]] [2025-05-12 22:04:58] - WebSocket client connected, args: ImmutableMultiDict([('EIO', '4'), ('transport', 'polling'), ('t', 'kn7pw5vt')])
# [[[ socket.io ]]] [2025-05-12 22:04:58] - ping: {'type': 'ping'}
# [[[ socket.io ]]] [2025-05-12 22:04:58] - ping: {'type': 'ping'}
# [[[ socket.io ]]] [2025-05-12 22:04:58] - ping: {'type': 'ping'}
# 127.0.0.1 - - [12/May/2025 22:04:59] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:59] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:04:59] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:00] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:00] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:00] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:01] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:01] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:01] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:02] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:02] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:02] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:03] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:03] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:03] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:04] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:04] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:04] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:05] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:05] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:05] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:06] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:06] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:06] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:07] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:07] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:07] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:08] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:08] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:08] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:09] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:09] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:09] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:10] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:10] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:10] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:11] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:11] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:11] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:12] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:12] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:12] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:13] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:13] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:13] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:14] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:14] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:14] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:16] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:16] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:16] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:17] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:17] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:17] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:18] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:18] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:18] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:19] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:19] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:19] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:20] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:20] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:20] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:21] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:21] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:21] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:22] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:22] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:22] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:23] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:23] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:23] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:24] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:24] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:24] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:25] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:25] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:25] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:26] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:26] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:26] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:26] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:26] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:27] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:27] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:27] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:28] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:28] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:29] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:29] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:30] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:30] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:31] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:31] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:32] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:32] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:33] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:33] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:34] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:34] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:35] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:35] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:36] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:36] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:37] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:37] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:38] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:38] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:39] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:39] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:40] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:40] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:41] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:41] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:42] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:42] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:43] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:43] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:44] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:44] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:45] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:45] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:46] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:46] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:47] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:47] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:48] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:48] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:49] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:49] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:50] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:50] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:51] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:51] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:52] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:52] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:53] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:53] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:54] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:54] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:55] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:55] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:56] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:56] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:57] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:57] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:58] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:58] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:59] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:05:59] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:00] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:00] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:01] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:01] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:02] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:02] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:03] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:03] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:04] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:04] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:05] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:05] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:06] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:06] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:07] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:07] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:08] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:08] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:09] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:09] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:10] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:10] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:11] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:11] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:12] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:12] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:13] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:13] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:14] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:14] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:14] "GET /socket.io/?EIO=4&transport=websocket&sid=vekuNO8jBnbRwfFNAAAA HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:15] "GET /socket.io/?EIO=4&transport=websocket&sid=gwEG8CX0oXIIK-KqAAAD HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:15] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:16] "GET /socket.io/?EIO=4&transport=websocket&sid=TMvyEdRxCB2UBNdNAAAC HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:16] "GET /state.json HTTP/1.1" 200 -
# 127.0.0.1 - - [12/May/2025 22:06:16] "GET /socket.io/?EIO=4&transport=websocket&sid=3j1sLl7LDeqOZnEzAAAE HTTP/1.1" 200 -

# %%
# setting up and serving the MDV project
base = os.path.expanduser('~/mdv')
project_path = os.path.join(base, 'spot') # defining the location where the project metadata will be stored
p = MDVProject(os.path.expanduser(project_path), delete_existing=False)

p.serve()
